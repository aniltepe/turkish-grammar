# %%
from enum import Enum
import json
import types

# %%
f = open('rules_250831.json')
RULES = json.load(f)
f = open('dictionary.json')
DICTIONARY = json.load(f)
f = open('sequences_250831.json')
SEQUENCES = json.load(f)

# %%
class _l(Enum): # letter
  SESLI = 1
  SESSIZ = 2
  KALIN = 3
  INCE = 4
  DUZ = 5
  YUVARLAK = 6
  GENIS = 7
  DAR = 8
  SERT = 9
  YUMUSAK = 10
  SUREKLI = 11
  SUREKSIZ = 12
  AKICI = 13
  SIZICI = 14
  KAYNASTIRMA = 15

# %%
class _w(Enum): # word
  ISIM = 1
  FIIL = 2
  SIFAT = 3
  ZARF = 4
  ZAMIR = 5

# %%
class _t(Enum): # tense
  GENIS = 1
  SIMDIKI_YOR = 2
  SIMDIKI_MAKTA = 3
  BILINENGECMIS = 4
  DUYULANGECMIS = 5
  GELECEK = 6

# %%
class _p(Enum): # pronoun
  BIRINCITEKIL = 1
  IKINCITEKIL = 2
  UCUNCUTEKIL = 3
  BIRINCICOGUL = 4
  IKINCICOGUL = 5
  UCUNCUCOGUL = 6

# %%
class _c(Enum): # compound
    BIRLESIKFIIL = 1
    YETERLILIK = 2
    TEZLIK = 3
    SUREKLILIK_DUR = 4
    SUREKLILIK_KAL = 5
    SUREKLILIK_GEL = 6
    YAKLASMA = 7

# %%
class _o(Enum):
    OLUMSUZLUK = 1
    GEREKLILIK = 2
    ISTEKKIPI = 3
    EMIRKIPI = 4
    SARTKIPI = 5
    HABEREDADI = 6

# %%
_a = {
  'a': {'index': 1, 'lower': 'a', 'upper': 'A', 'tags': [_l.SESLI, _l.KALIN, _l.DUZ, _l.GENIS] },
  'b': {'index': 2, 'lower': 'b', 'upper': 'B', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKSIZ] },
  'c': {'index': 3, 'lower': 'c', 'upper': 'C', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKSIZ] },
  'ç': {'index': 4, 'lower': 'ç', 'upper': 'Ç', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKSIZ] },
  'd': {'index': 5, 'lower': 'd', 'upper': 'D', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKSIZ] },
  'e': {'index': 6, 'lower': 'e', 'upper': 'E', 'tags': [_l.SESLI, _l.INCE, _l.DUZ, _l.GENIS] },
  'f': {'index': 7, 'lower': 'f', 'upper': 'F', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKLI] },
  'g': {'index': 8, 'lower': 'g', 'upper': 'G', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKSIZ] },
  'ğ': {'index': 9, 'lower': 'ğ', 'upper': 'Ğ', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'h': {'index': 10, 'lower': 'h', 'upper': 'H', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKLI] },
  'ı': {'index': 11, 'lower': 'ı', 'upper': 'I', 'tags': [_l.SESLI, _l.KALIN, _l.DUZ, _l.DAR] },
  'i': {'index': 12, 'lower': 'i', 'upper': 'İ', 'tags': [_l.SESLI, _l.INCE, _l.DUZ, _l.DAR] },
  'j': {'index': 13, 'lower': 'j', 'upper': 'J', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'k': {'index': 14, 'lower': 'k', 'upper': 'K', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKSIZ] },
  'l': {'index': 15, 'lower': 'l', 'upper': 'L', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'm': {'index': 16, 'lower': 'm', 'upper': 'M', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'n': {'index': 17, 'lower': 'n', 'upper': 'N', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI, _l.KAYNASTIRMA] },
  'o': {'index': 18, 'lower': 'o', 'upper': 'O', 'tags': [_l.SESLI, _l.KALIN, _l.YUVARLAK, _l.GENIS] },
  'ö': {'index': 19, 'lower': 'ö', 'upper': 'Ö', 'tags': [_l.SESLI, _l.INCE, _l.YUVARLAK, _l.GENIS] },
  'p': {'index': 20, 'lower': 'p', 'upper': 'P', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKSIZ] },
  'r': {'index': 21, 'lower': 'r', 'upper': 'R', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  's': {'index': 22, 'lower': 's', 'upper': 'S', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKLI, _l.KAYNASTIRMA] },
  'ş': {'index': 23, 'lower': 'ş', 'upper': 'Ş', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKLI, _l.KAYNASTIRMA] },
  't': {'index': 24, 'lower': 't', 'upper': 'T', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKSIZ] },
  'u': {'index': 25, 'lower': 'u', 'upper': 'U', 'tags': [_l.SESLI, _l.KALIN, _l.YUVARLAK, _l.DAR] },
  'ü': {'index': 26, 'lower': 'ü', 'upper': 'Ü', 'tags': [_l.SESLI, _l.INCE, _l.YUVARLAK, _l.DAR] },
  'v': {'index': 27, 'lower': 'v', 'upper': 'V', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'y': {'index': 28, 'lower': 'y', 'upper': 'Y', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI, _l.KAYNASTIRMA] },
  'z': {'index': 29, 'lower': 'z', 'upper': 'Z', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] }
}

# %%
def FIND_LETTERS(tags):
  return [_a[l] for l in _a if all(t in _a[l]['tags'] for t in tags)]

# %%
def CHECK_LETTER(letter, tags):
    return all(t in letter['tags'] for t in tags)

# %%
def REPLACE_TAGS(tags, old, new):
    return [t if t != old else new for t in tags]

# %%
class Word:
  def __init__(self, word, type=None):
    self.root = word
    if type == _w.FIIL:
      self.root = word[:-3]
    self.letters, self.vowels, self.consonants = self.set_letters(self.root)
    self.default = word
    self.type = type

    self.applied = []
    self.ambiguous = False

    self.next_word = None
    self.prev_word = None
    self.punct_after = None
  
  def word(self, type='lower'):
    w = (''.join([l['upper'] for l in self.letters]) if type == 'upper'
         else ''.join([l['upper'] if i == 0 else l['lower'] for i, l in enumerate(self.letters)]) if type == 'pascal' 
         else ''.join([l['lower'] for l in self.letters]))
    return w

  def append(self, suffix, code, prev_suffix=None):
    # print(''.join([l['lower'] for l in suffix]))
    self._suffix = (suffix, code)
    if len(suffix) > 0:
      ns = types.SimpleNamespace()
      setattr(ns, 'name', '_APPEND')
      self.apply_rule(ns)
      count = len(self.letters)
      self.letters.extend(self._suffix[0])
      self.vowels.extend([dict(l, **{'w_idx': count + i}) for i, l in enumerate(self._suffix[0]) if _l.SESLI in l['tags']])
      self.consonants.extend([dict(l, **{'w_idx': count + i}) for i, l in enumerate(self._suffix[0]) if _l.SESSIZ in l['tags']])
    self.applied.append({'code': code, 'type': 'append', 'field1': self._suffix[0]})
    self._suffix = prev_suffix
    
  def replace(self, idx, new, code):
    old = self.letters[idx]
    self.letters = [l if i != idx else new for i, l in enumerate(self.letters)]
    if _l.SESLI in new['tags']:
      self.vowels = [l if l['w_idx'] != idx else dict(new, **{'w_idx': idx}) for l in self.vowels]
    elif _l.SESSIZ in new['tags']:
      self.consonants = [l if l['w_idx'] != idx else dict(new, **{'w_idx': idx}) for l in self.consonants]
    self.applied.append({'code': code, 'type': 'replace', 'field1': (old, idx), 'field2': new})
  
  def replace_suffix(self, idx, new, code):
    old = self._suffix[0][idx]
    self._suffix = ([l if i != idx else new for i, l in enumerate(self._suffix[0])], self._suffix[1])
    self.applied.append({'code': code, 'type': 'replace', 'field1': (old, len(self.letters) + idx), 'field2': new})

  def apply_rule(self, type):
    rules = [r for r in RULES if r['type'] == type.name]
    var_match = {
      'self': self,
      '_l': _l,
      '_w': _w,
      '_a': _a,
      'CHECK_LETTER': CHECK_LETTER,
      'FIND_LETTERS': FIND_LETTERS,
      'REPLACE_TAGS': REPLACE_TAGS
    }
    for rule in rules:
      if 'if' not in rule or eval(' and '.join(rule['if']), var_match):
        # print(rule['id'])
        for do in rule['do']:
          eval(do, var_match)
        break

  def check_applied(self, codes, type, idx=None):
    if idx == None:
      return (all(t in [a['code'] for a in self.applied] for t in codes) if type == 'allin'
              else all(t not in [a['code'] for a in self.applied] for t in codes) if type == 'allnotin'
              else any(t in [a['code'] for a in self.applied] for t in codes) if type == 'anyin'
              else any(t not in [a['code'] for a in self.applied] for t in codes) if type == 'anynotin'
              else not(any(t in [a['code'] for a in self.applied] for t in codes)) if type == 'notanyin'
              else None)
    if (idx < 0 and idx * -1 > len(self.applied)) or (idx >= 0 and idx >= len(self.applied)):
      return True if type == 'notin' else False if type == 'in' else None
    return (self.applied[idx]['code'] in codes if type == 'in'
            else self.applied[idx]['code'] not in codes if type == 'notin'
            else None)

  def clone(self):
    w_new = Word('')
    w_new.letters = self.letters[:]
    w_new.vowels = self.vowels[:]
    w_new.consonants = self.consonants[:]
    w_new.applied = self.applied[:]
    w_new.type = self.type
    w_new.default = self.default
    w_new.root = self.root
    return w_new
  
  @staticmethod
  def set_letters(word):
    letters = [_a[l] for l in Word.lower(word)]
    vowels = [dict(_a[l], **{'w_idx': i}) for i, l in enumerate(Word.lower(word)) if _l.SESLI in _a[l]['tags']]
    consonants = [dict(_a[l], **{'w_idx': i}) for i, l in enumerate(Word.lower(word)) if _l.SESSIZ in _a[l]['tags']]
    return letters, vowels, consonants
  
  @staticmethod
  def lower(word):
    return word.replace('İ','i').replace('I','ı').lower()
  
  @staticmethod
  def upper(word):
    return word.replace('i','İ').upper()

# %%
class Sentence:
    def __init__(self, sentence):
        self.words = [Word(w) for w in sentence.split(' ')]
        self.punctuation = None

# %%
TEST_PARAGRAPH = 'Çalışma hayatına dahil edilen çocuklar oyun oynama, öğrenme, hayal kurma ve dinlenme gibi temel ihtiyaçlardan mahrum bırakılmaktadır. Çalışan çocuklar, çocukluklarını yaşayamamanın ötesinde ağır ve sağlıksız çalışma koşulları nedeniyle bedensel, ruhsal ve sosyal anlamda zarar görme tehlikesiyle karşı karşıya kalmaktadır. Aslında hemen hemen her evde belirli bir yaşın üzerindeki çocuklar ev işlerinde çalışırlar. Bu çalışma kimi zaman küçük bir kardeşin bakımı veya evin derlenip toparlanması, kimi zaman da tarla ve bahçe işlerine yardım etme şeklinde olabilir. Bunlar genellikle yarı zamanlı, belirli bir zamanlaması olmayan, o andaki ihtiyaca göre şekillenen geçici işlerdir. Oysa çalışan çocuk kavramı ile çocuğun kendi evinin dışında başkasının işinde veya kendi ailesinin işinde üretime doğrudan katkı sağlayacak şekilde çalışması kastedilmektedir.'

# %%
TEST_SENTENCE = 'Bilirsin.'

# %%
set([r["type"] for r in RULES])
# Out:
# {'BILINENGECMIS',
#  'BIRINCICOGUL',
#  'BIRINCITEKIL',
#  'BIRLESIKFIIL',
#  'DUYULANGECMIS',
#  'GELECEK',
#  'GENIS',
#  'GEREKLILIK',
#  'IKINCICOGUL',
#  'IKINCITEKIL',
#  'MASTAR',
#  'OLUMSUZLUK',
#  'SARTKIPI',
#  'SIMDIKI_MAKTA',
#  'SIMDIKI_YOR',
#  'TEZLIK',
#  'UCUNCUCOGUL',
#  'UCUNCUTEKIL',
#  'YETERLILIK',
#  '_APPEND'}

# %%
w1 = Word('gelmek', _w.FIIL)
results = []
var_match = {'_w': _w, '_t': _t, '_c': _c, '_p': _p, '_o': _o}
for SEQUENCE in SEQUENCES:
    w_root = w1.clone()
    word_build = [[w_root]]
    for sequence in SEQUENCE['seq']:
        rules, include_prev = [], False
        rules = sequence if isinstance(sequence, list) else [sequence]
        possibles = []
        for rule in rules:
            if rule.endswith("?"):
                rule = rule[:-1]
                include_prev = True
            obj = eval(rule, var_match)
            for last_possible in word_build[-1]:
                if include_prev:
                    possibles.append(last_possible.clone())
                if type(obj) == type(Enum):
                    for i in obj:
                        w_new = last_possible.clone()
                        w_new.apply_rule(i)
                        possibles.append(w_new)
                elif type(type(obj)) == type(Enum):
                    w_new = last_possible.clone()
                    w_new.apply_rule(obj)
                    possibles.append(w_new)           

        word_build.append(possibles)
        print([w.word() for w in possibles])

    # print([_.word() for w in word_build for _ in w])
    for all_possible in word_build[-1]:
        possible = (all_possible.word(), [a['code'] for a in all_possible.applied])
        results.append(possible)
        # if possible not in results:
        #     results.append(possible)
        # else:
        #     print(possible, "already in the list")
results
# Out:
# ['gel', 'gelme']
# ['gelir', 'geliyor', 'gelmekte', 'geldi', 'gelmiş', 'gelecek', 'gelme', 'gelmiyor', 'gelmemekte', 'gelmedi', 'gelmemiş', 'gelmeyecek']
# ['gelirim', 'gelirsin', 'gelir', 'geliriz', 'gelirsiniz', 'gelirler', 'geliyorum', 'geliyorsun', 'geliyor', 'geliyoruz', 'geliyorsunuz', 'geliyorlar', 'gelmekteyim', 'gelmektesin', 'gelmekte', 'gelmekteyiz', 'gelmektesiniz', 'gelmekteler', 'geldim', 'geldin', 'geldi', 'geldik', 'geldiniz', 'geldiler', 'gelmişim', 'gelmişsin', 'gelmiş', 'gelmişiz', 'gelmişsiniz', 'gelmişler', 'geleceğim', 'geleceksin', 'gelecek', 'geleceğiz', 'geleceksiniz', 'gelecekler', 'gelmem', 'gelmezsin', 'gelmez', 'gelmeyiz', 'gelmezsiniz', 'gelmezler', 'gelmiyorum', 'gelmiyorsun', 'gelmiyor', 'gelmiyoruz', 'gelmiyorsunuz', 'gelmiyorlar', 'gelmemekteyim', 'gelmemektesin', 'gelmemekte', 'gelmemekteyiz', 'gelmemektesiniz', 'gelmemekteler', 'gelmedim', 'gelmedin', 'gelmedi', 'gelmedik', 'gelmediniz', 'gelmediler', 'gelmemişim', 'gelmemişsin', 'gelmemiş', 'gelmemişiz', 'gelmemişsiniz', 'gelmemişler', 'gelmeyeceğim', 'gelmeyeceksin', 'gelmeyecek', 'gelmeyeceğiz', 'gelmeyeceksiniz', 'gelmeyecekler']
# ['gel', 'gelme']
# ['gelebil', 'gelmeyebil']
# ['gelebilir', 'gelebiliyor', 'gelebilmekte', 'gelebildi', 'gelebilmiş', 'gelebilecek', 'gelmeyebilir', 'gelmeyebiliyor', 'gelmeyebilmekte', 'gelmeyebildi', 'gelmeyebilmiş', 'gelmeyebilecek']
# ['gelebilirim', 'gelebilirsin', 'gelebilir', 'gelebiliriz', 'gelebilirsiniz', 'gelebilirler', 'gelebiliyorum', 'gelebiliyorsun', 'gelebiliyor', 'gelebiliyoruz', 'gelebiliyorsunuz', 'gelebiliyorlar', 'gelebilmekteyim', 'gelebilmektesin', 'gelebilmekte', 'gelebilmekteyiz', 'gelebilmektesiniz', 'gelebilmekteler', 'gelebildim', 'gelebildin', 'gelebildi', 'gelebildik', 'gelebildiniz', 'gelebildiler', 'gelebilmişim', 'gelebilmişsin', 'gelebilmiş', 'gelebilmişiz', 'gelebilmişsiniz', 'gelebilmişler', 'gelebileceğim', 'gelebileceksin', 'gelebilecek', 'gelebileceğiz', 'gelebileceksiniz', 'gelebilecekler', 'gelmeyebilirim', 'gelmeyebilirsin', 'gelmeyebilir', 'gelmeyebiliriz', 'gelmeyebilirsiniz', 'gelmeyebilirler', 'gelmeyebiliyorum', 'gelmeyebiliyorsun', 'gelmeyebiliyor', 'gelmeyebiliyoruz', 'gelmeyebiliyorsunuz', 'gelmeyebiliyorlar', 'gelmeyebilmekteyim', 'gelmeyebilmektesin', 'gelmeyebilmekte', 'gelmeyebilmekteyiz', 'gelmeyebilmektesiniz', 'gelmeyebilmekteler', 'gelmeyebildim', 'gelmeyebildin', 'gelmeyebildi', 'gelmeyebildik', 'gelmeyebildiniz', 'gelmeyebildiler', 'gelmeyebilmişim', 'gelmeyebilmişsin', 'gelmeyebilmiş', 'gelmeyebilmişiz', 'gelmeyebilmişsiniz', 'gelmeyebilmişler', 'gelmeyebileceğim', 'gelmeyebileceksin', 'gelmeyebilecek', 'gelmeyebileceğiz', 'gelmeyebileceksiniz', 'gelmeyebilecekler']
# ['gel', 'gelme']
# ['gelmeli', 'gelmemeli', 'gelse', 'gelmese']
# ['gelmeliyim', 'gelmelisin', 'gelmeli', 'gelmeliyiz', 'gelmelisiniz', 'gelmeliler', 'gelmemeliyim', 'gelmemelisin', 'gelmemeli', 'gelmemeliyiz', 'gelmemelisiniz', 'gelmemeliler', 'gelsem', 'gelsen', 'gelse', 'gelsek', 'gelseniz', 'gelseler', 'gelmesem', 'gelmesen', 'gelmese', 'gelmesek', 'gelmeseniz', 'gelmeseler']
# ['gel', 'gelme']
# ['gelir', 'geliyor', 'gelmekte', 'geldi', 'gelmiş', 'gelecek', 'gelme', 'gelmiyor', 'gelmemekte', 'gelmedi', 'gelmemiş', 'gelmeyecek']
# ['gelirse', 'geliyorsa', 'gelmekteyse', 'geldiyse', 'gelmişse', 'gelecekse', 'gelmezse', 'gelmiyorsa', 'gelmemekteyse', 'gelmediyse', 'gelmemişse', 'gelmeyecekse']
# ['gelirsem', 'gelirsen', 'gelirse', 'gelirsek', 'gelirseniz', 'gelirseler', 'geliyorsam', 'geliyorsan', 'geliyorsa', 'geliyorsak', 'geliyorsanız', 'geliyorsalar', 'gelmekteysem', 'gelmekteysen', 'gelmekteyse', 'gelmekteysek', 'gelmekteyseniz', 'gelmekteyseler', 'geldiysem', 'geldiysen', 'geldiyse', 'geldiysek', 'geldiyseniz', 'geldiyseler', 'gelmişsem', 'gelmişsen', 'gelmişse', 'gelmişsek', 'gelmişseniz', 'gelmişseler', 'geleceksem', 'geleceksen', 'gelecekse', 'geleceksek', 'gelecekseniz', 'gelecekseler', 'gelmezsem', 'gelmezsen', 'gelmezse', 'gelmezsek', 'gelmezseniz', 'gelmezseler', 'gelmiyorsam', 'gelmiyorsan', 'gelmiyorsa', 'gelmiyorsak', 'gelmiyorsanız', 'gelmiyorsalar', 'gelmemekteysem', 'gelmemekteysen', 'gelmemekteyse', 'gelmemekteysek', 'gelmemekteyseniz', 'gelmemekteyseler', 'gelmediysem', 'gelmediysen', 'gelmediyse', 'gelmediysek', 'gelmediyseniz', 'gelmediyseler', 'gelmemişsem', 'gelmemişsen', 'gelmemişse', 'gelmemişsek', 'gelmemişseniz', 'gelmemişseler', 'gelmeyeceksem', 'gelmeyeceksen', 'gelmeyecekse', 'gelmeyeceksek', 'gelmeyecekseniz', 'gelmeyecekseler']
# ['gele']
# ['geleme']
# ['geleme', 'gelemeyebil']
# ['geleme', 'gelemiyor', 'gelememekte', 'gelemedi', 'gelememiş', 'gelemeyecek', 'gelemeyebilir', 'gelemeyebiliyor', 'gelemeyebilmekte', 'gelemeyebildi', 'gelemeyebilmiş', 'gelemeyebilecek']
# ['gelemem', 'gelemezsin', 'gelemez', 'gelemeyiz', 'gelemezsiniz', 'gelemezler', 'gelemiyorum', 'gelemiyorsun', 'gelemiyor', 'gelemiyoruz', 'gelemiyorsunuz', 'gelemiyorlar', 'gelememekteyim', 'gelememektesin', 'gelememekte', 'gelememekteyiz', 'gelememektesiniz', 'gelememekteler', 'gelemedim', 'gelemedin', 'gelemedi', 'gelemedik', 'gelemediniz', 'gelemediler', 'gelememişim', 'gelememişsin', 'gelememiş', 'gelememişiz', 'gelememişsiniz', 'gelememişler', 'gelemeyeceğim', 'gelemeyeceksin', 'gelemeyecek', 'gelemeyeceğiz', 'gelemeyeceksiniz', 'gelemeyecekler', 'gelemeyebilirim', 'gelemeyebilirsin', 'gelemeyebilir', 'gelemeyebiliriz', 'gelemeyebilirsiniz', 'gelemeyebilirler', 'gelemeyebiliyorum', 'gelemeyebiliyorsun', 'gelemeyebiliyor', 'gelemeyebiliyoruz', 'gelemeyebiliyorsunuz', 'gelemeyebiliyorlar', 'gelemeyebilmekteyim', 'gelemeyebilmektesin', 'gelemeyebilmekte', 'gelemeyebilmekteyiz', 'gelemeyebilmektesiniz', 'gelemeyebilmekteler', 'gelemeyebildim', 'gelemeyebildin', 'gelemeyebildi', 'gelemeyebildik', 'gelemeyebildiniz', 'gelemeyebildiler', 'gelemeyebilmişim', 'gelemeyebilmişsin', 'gelemeyebilmiş', 'gelemeyebilmişiz', 'gelemeyebilmişsiniz', 'gelemeyebilmişler', 'gelemeyebileceğim', 'gelemeyebileceksin', 'gelemeyebilecek', 'gelemeyebileceğiz', 'gelemeyebileceksiniz', 'gelemeyebilecekler']
# ['gel', 'gelme']
# ['gelir', 'geliyor', 'gelmekte', 'geldi', 'gelmiş', 'gelecek', 'gelme', 'gelmiyor', 'gelmemekte', 'gelmedi', 'gelmemiş', 'gelmeyecek']
# ['gelirmiş', 'geliyormuş', 'gelmekteymiş', 'geldiymiş', 'gelmişmiş', 'gelecekmiş', 'gelmezmiş', 'gelmiyormuş', 'gelmemekteymiş', 'gelmediymiş', 'gelmemişmiş', 'gelmeyecekmiş', 'gelirdi', 'geliyordu', 'gelmekteydi', 'geldiydi', 'gelmişti', 'gelecekti', 'gelmezdi', 'gelmiyordu', 'gelmemekteydi', 'gelmediydi', 'gelmemişti', 'gelmeyecekti']
# ['gelirmişim', 'gelirmişsin', 'gelirmiş', 'gelirmişiz', 'gelirmişsiniz', 'gelirmişler', 'geliyormuşum', 'geliyormuşsun', 'geliyormuş', 'geliyormuşuz', 'geliyormuşsunuz', 'geliyormuşlar', 'gelmekteymişim', 'gelmekteymişsin', 'gelmekteymiş', 'gelmekteymişiz', 'gelmekteymişsiniz', 'gelmekteymişler', 'geldiymişim', 'geldiymişsin', 'geldiymiş', 'geldiymişiz', 'geldiymişsiniz', 'geldiymişler', 'gelmişmişim', 'gelmişmişsin', 'gelmişmiş', 'gelmişmişiz', 'gelmişmişsiniz', 'gelmişmişler', 'gelecekmişim', 'gelecekmişsin', 'gelecekmiş', 'gelecekmişiz', 'gelecekmişsiniz', 'gelecekmişler', 'gelmezmişim', 'gelmezmişsin', 'gelmezmiş', 'gelmezmişiz', 'gelmezmişsiniz', 'gelmezmişler', 'gelmiyormuşum', 'gelmiyormuşsun', 'gelmiyormuş', 'gelmiyormuşuz', 'gelmiyormuşsunuz', 'gelmiyormuşlar', 'gelmemekteymişim', 'gelmemekteymişsin', 'gelmemekteymiş', 'gelmemekteymişiz', 'gelmemekteymişsiniz', 'gelmemekteymişler', 'gelmediymişim', 'gelmediymişsin', 'gelmediymiş', 'gelmediymişiz', 'gelmediymişsiniz', 'gelmediymişler', 'gelmemişmişim', 'gelmemişmişsin', 'gelmemişmiş', 'gelmemişmişiz', 'gelmemişmişsiniz', 'gelmemişmişler', 'gelmeyecekmişim', 'gelmeyecekmişsin', 'gelmeyecekmiş', 'gelmeyecekmişiz', 'gelmeyecekmişsiniz', 'gelmeyecekmişler', 'gelirdim', 'gelirdin', 'gelirdi', 'gelirdik', 'gelirdiniz', 'gelirdiler', 'geliyordum', 'geliyordun', 'geliyordu', 'geliyorduk', 'geliyordunuz', 'geliyordular', 'gelmekteydim', 'gelmekteydin', 'gelmekteydi', 'gelmekteydik', 'gelmekteydiniz', 'gelmekteydiler', 'geldiydim', 'geldiydin', 'geldiydi', 'geldiydik', 'geldiydiniz', 'geldiydiler', 'gelmiştim', 'gelmiştin', 'gelmişti', 'gelmiştik', 'gelmiştiniz', 'gelmiştiler', 'gelecektim', 'gelecektin', 'gelecekti', 'gelecektik', 'gelecektiniz', 'gelecektiler', 'gelmezdim', 'gelmezdin', 'gelmezdi', 'gelmezdik', 'gelmezdiniz', 'gelmezdiler', 'gelmiyordum', 'gelmiyordun', 'gelmiyordu', 'gelmiyorduk', 'gelmiyordunuz', 'gelmiyordular', 'gelmemekteydim', 'gelmemekteydin', 'gelmemekteydi', 'gelmemekteydik', 'gelmemekteydiniz', 'gelmemekteydiler', 'gelmediydim', 'gelmediydin', 'gelmediydi', 'gelmediydik', 'gelmediydiniz', 'gelmediydiler', 'gelmemiştim', 'gelmemiştin', 'gelmemişti', 'gelmemiştik', 'gelmemiştiniz', 'gelmemiştiler', 'gelmeyecektim', 'gelmeyecektin', 'gelmeyecekti', 'gelmeyecektik', 'gelmeyecektiniz', 'gelmeyecektiler']
# ['gel', 'gelme']
# ['gelse', 'gelmese']
# ['gelseymiş', 'gelmeseymiş', 'gelseydi', 'gelmeseydi']
# ['gelseymişim', 'gelseymişsin', 'gelseymiş', 'gelseymişiz', 'gelseymişsiniz', 'gelseymişler', 'gelmeseymişim', 'gelmeseymişsin', 'gelmeseymiş', 'gelmeseymişiz', 'gelmeseymişsiniz', 'gelmeseymişler', 'gelseydim', 'gelseydin', 'gelseydi', 'gelseydik', 'gelseydiniz', 'gelseydiler', 'gelmeseydim', 'gelmeseydin', 'gelmeseydi', 'gelmeseydik', 'gelmeseydiniz', 'gelmeseydiler']
# ['gel', 'gelme']
# ['gelmeli', 'gelmemeli']
# ['gelmeliymiş', 'gelmemeliymiş', 'gelmeliydi', 'gelmemeliydi']
# ['gelmeliymişim', 'gelmeliymişsin', 'gelmeliymiş', 'gelmeliymişiz', 'gelmeliymişsiniz', 'gelmeliymişler', 'gelmemeliymişim', 'gelmemeliymişsin', 'gelmemeliymiş', 'gelmemeliymişiz', 'gelmemeliymişsiniz', 'gelmemeliymişler', 'gelmeliydim', 'gelmeliydin', 'gelmeliydi', 'gelmeliydik', 'gelmeliydiniz', 'gelmeliydiler', 'gelmemeliydim', 'gelmemeliydin', 'gelmemeliydi', 'gelmemeliydik', 'gelmemeliydiniz', 'gelmemeliydiler']
# ['gel', 'gelme']
# ['gelmeli', 'gelmemeli']
# ['gelmeliyse', 'gelmemeliyse']
# ['gelmeliysem', 'gelmeliysen', 'gelmeliyse', 'gelmeliysek', 'gelmeliyseniz', 'gelmeliyseler', 'gelmemeliysem', 'gelmemeliysen', 'gelmemeliyse', 'gelmemeliysek', 'gelmemeliyseniz', 'gelmemeliyseler']
# ['gel', 'gelme']
# ['geliyor', 'gelmiyor', 'gelmekte', 'gelmemekte']
# ['geliyorum', 'geliyorsun', 'geliyor', 'geliyoruz', 'geliyorsunuz', 'geliyorlar', 'gelmiyorum', 'gelmiyorsun', 'gelmiyor', 'gelmiyoruz', 'gelmiyorsunuz', 'gelmiyorlar', 'gelmekteyim', 'gelmektesin', 'gelmekte', 'gelmekteyiz', 'gelmektesiniz', 'gelmekteler', 'gelmemekteyim', 'gelmemektesin', 'gelmemekte', 'gelmemekteyiz', 'gelmemektesiniz', 'gelmemekteler']
# ['geliyorumdur', 'geliyorsundur', 'geliyordur', 'geliyoruzdur', 'geliyorsunuzdur', 'geliyorlardır', 'gelmiyorumdur', 'gelmiyorsundur', 'gelmiyordur', 'gelmiyoruzdur', 'gelmiyorsunuzdur', 'gelmiyorlardır', 'gelmekteyimdir', 'gelmektesindir', 'gelmektedir', 'gelmekteyizdir', 'gelmektesinizdir', 'gelmektelerdir', 'gelmemekteyimdir', 'gelmemektesindir', 'gelmemektedir', 'gelmemekteyizdir', 'gelmemektesinizdir', 'gelmemektelerdir']
# ['gel', 'gelme']
# ['gelmiş', 'gelmemiş', 'gelecek', 'gelmeyecek']
# ['gelmişim', 'gelmişsin', 'gelmiş', 'gelmişiz', 'gelmişsiniz', 'gelmişler', 'gelmemişim', 'gelmemişsin', 'gelmemiş', 'gelmemişiz', 'gelmemişsiniz', 'gelmemişler', 'geleceğim', 'geleceksin', 'gelecek', 'geleceğiz', 'geleceksiniz', 'gelecekler', 'gelmeyeceğim', 'gelmeyeceksin', 'gelmeyecek', 'gelmeyeceğiz', 'gelmeyeceksiniz', 'gelmeyecekler']
# ['gelmişimdir', 'gelmişsindir', 'gelmiştir', 'gelmişizdir', 'gelmişsinizdir', 'gelmişlerdir', 'gelmemişimdir', 'gelmemişsindir', 'gelmemiştir', 'gelmemişizdir', 'gelmemişsinizdir', 'gelmemişlerdir', 'geleceğimdir', 'geleceksindir', 'gelecektir', 'geleceğizdir', 'geleceksinizdir', 'geleceklerdir', 'gelmeyeceğimdir', 'gelmeyeceksindir', 'gelmeyecektir', 'gelmeyeceğizdir', 'gelmeyeceksinizdir', 'gelmeyeceklerdir']
# ['gel', 'gelme']
# ['gelmeli', 'gelmemeli']
# ['gelmeliyim', 'gelmelisin', 'gelmeli', 'gelmeliyiz', 'gelmelisiniz', 'gelmeliler', 'gelmemeliyim', 'gelmemelisin', 'gelmemeli', 'gelmemeliyiz', 'gelmemelisiniz', 'gelmemeliler']
# ['gelmeliyimdir', 'gelmelisindir', 'gelmelidir', 'gelmeliyizdir', 'gelmelisinizdir', 'gelmelilerdir', 'gelmemeliyimdir', 'gelmemelisindir', 'gelmemelidir', 'gelmemeliyizdir', 'gelmemelisinizdir', 'gelmemelilerdir']
# [('gelirim', ['GENIS', 'BIRINCITEKIL']),
#  ('gelirsin', ['GENIS', 'IKINCITEKIL']),
#  ('gelir', ['GENIS', 'UCUNCUTEKIL']),
#  ('geliriz', ['GENIS', 'BIRINCICOGUL']),
#  ('gelirsiniz', ['GENIS', 'IKINCICOGUL']),
#  ('gelirler', ['GENIS', 'UCUNCUCOGUL']),
#  ('geliyorum', ['SIMDIKI_YOR', 'BIRINCITEKIL']),
#  ('geliyorsun', ['SIMDIKI_YOR', 'IKINCITEKIL']),
#  ('geliyor', ['SIMDIKI_YOR', 'UCUNCUTEKIL']),
#  ('geliyoruz', ['SIMDIKI_YOR', 'BIRINCICOGUL']),
#  ('geliyorsunuz', ['SIMDIKI_YOR', 'IKINCICOGUL']),
#  ('geliyorlar', ['SIMDIKI_YOR', 'UCUNCUCOGUL']),
#  ('gelmekteyim', ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL']),
#  ('gelmektesin', ['SIMDIKI_MAKTA', 'IKINCITEKIL']),
#  ('gelmekte', ['SIMDIKI_MAKTA', 'UCUNCUTEKIL']),
#  ('gelmekteyiz', ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL']),
#  ('gelmektesiniz', ['SIMDIKI_MAKTA', 'IKINCICOGUL']),
#  ('gelmekteler', ['SIMDIKI_MAKTA', 'UCUNCUCOGUL']),
#  ('geldim', ['BILINENGECMIS', 'BIRINCITEKIL']),
#  ('geldin', ['BILINENGECMIS', 'IKINCITEKIL']),
#  ('geldi', ['BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('geldik', ['BILINENGECMIS', 'BIRINCICOGUL']),
#  ('geldiniz', ['BILINENGECMIS', 'IKINCICOGUL']),
#  ('geldiler', ['BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmişim', ['DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmişsin', ['DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmiş', ['DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmişiz', ['DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmişsiniz', ['DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmişler', ['DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('geleceğim', ['GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCITEKIL']),
#  ('geleceksin', ['GELECEK', 'IKINCITEKIL']),
#  ('gelecek', ['GELECEK', 'UCUNCUTEKIL']),
#  ('geleceğiz', ['GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCICOGUL']),
#  ('geleceksiniz', ['GELECEK', 'IKINCICOGUL']),
#  ('gelecekler', ['GELECEK', 'UCUNCUCOGUL']),
#  ('gelmem', ['OLUMSUZLUK', 'GENIS', 'BIRINCITEKIL']),
#  ('gelmezsin', ['OLUMSUZLUK', 'GENIS', 'IKINCITEKIL']),
#  ('gelmez', ['OLUMSUZLUK', 'GENIS', 'UCUNCUTEKIL']),
#  ('gelmeyiz', ['OLUMSUZLUK', 'GENIS', 'KAYNASTIRMA', 'BIRINCICOGUL']),
#  ('gelmezsiniz', ['OLUMSUZLUK', 'GENIS', 'IKINCICOGUL']),
#  ('gelmezler', ['OLUMSUZLUK', 'GENIS', 'UCUNCUCOGUL']),
#  ('gelmiyorum',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'BIRINCITEKIL']),
#  ('gelmiyorsun',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'IKINCITEKIL']),
#  ('gelmiyor', ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'UCUNCUTEKIL']),
#  ('gelmiyoruz',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'BIRINCICOGUL']),
#  ('gelmiyorsunuz',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'IKINCICOGUL']),
#  ('gelmiyorlar',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'UCUNCUCOGUL']),
#  ('gelmemekteyim',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL']),
#  ('gelmemektesin', ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCITEKIL']),
#  ('gelmemekte', ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL']),
#  ('gelmemekteyiz',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL']),
#  ('gelmemektesiniz', ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCICOGUL']),
#  ('gelmemekteler', ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL']),
#  ('gelmedim', ['OLUMSUZLUK', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelmedin', ['OLUMSUZLUK', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelmedi', ['OLUMSUZLUK', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelmedik', ['OLUMSUZLUK', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelmediniz', ['OLUMSUZLUK', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelmediler', ['OLUMSUZLUK', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmemişim', ['OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmemişsin', ['OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmemiş', ['OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmemişiz', ['OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmemişsiniz', ['OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmemişler', ['OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeyeceğim',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCITEKIL']),
#  ('gelmeyeceksin', ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCITEKIL']),
#  ('gelmeyecek', ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUTEKIL']),
#  ('gelmeyeceğiz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCICOGUL']),
#  ('gelmeyeceksiniz', ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCICOGUL']),
#  ('gelmeyecekler', ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUCOGUL']),
#  ('gelebilirim', ['YETERLILIK', 'GENIS', 'BIRINCITEKIL']),
#  ('gelebilirsin', ['YETERLILIK', 'GENIS', 'IKINCITEKIL']),
#  ('gelebilir', ['YETERLILIK', 'GENIS', 'UCUNCUTEKIL']),
#  ('gelebiliriz', ['YETERLILIK', 'GENIS', 'BIRINCICOGUL']),
#  ('gelebilirsiniz', ['YETERLILIK', 'GENIS', 'IKINCICOGUL']),
#  ('gelebilirler', ['YETERLILIK', 'GENIS', 'UCUNCUCOGUL']),
#  ('gelebiliyorum', ['YETERLILIK', 'SIMDIKI_YOR', 'BIRINCITEKIL']),
#  ('gelebiliyorsun', ['YETERLILIK', 'SIMDIKI_YOR', 'IKINCITEKIL']),
#  ('gelebiliyor', ['YETERLILIK', 'SIMDIKI_YOR', 'UCUNCUTEKIL']),
#  ('gelebiliyoruz', ['YETERLILIK', 'SIMDIKI_YOR', 'BIRINCICOGUL']),
#  ('gelebiliyorsunuz', ['YETERLILIK', 'SIMDIKI_YOR', 'IKINCICOGUL']),
#  ('gelebiliyorlar', ['YETERLILIK', 'SIMDIKI_YOR', 'UCUNCUCOGUL']),
#  ('gelebilmekteyim',
#   ['YETERLILIK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL']),
#  ('gelebilmektesin', ['YETERLILIK', 'SIMDIKI_MAKTA', 'IKINCITEKIL']),
#  ('gelebilmekte', ['YETERLILIK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL']),
#  ('gelebilmekteyiz',
#   ['YETERLILIK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL']),
#  ('gelebilmektesiniz', ['YETERLILIK', 'SIMDIKI_MAKTA', 'IKINCICOGUL']),
#  ('gelebilmekteler', ['YETERLILIK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL']),
#  ('gelebildim', ['YETERLILIK', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelebildin', ['YETERLILIK', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelebildi', ['YETERLILIK', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelebildik', ['YETERLILIK', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelebildiniz', ['YETERLILIK', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelebildiler', ['YETERLILIK', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelebilmişim', ['YETERLILIK', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelebilmişsin', ['YETERLILIK', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelebilmiş', ['YETERLILIK', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelebilmişiz', ['YETERLILIK', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelebilmişsiniz', ['YETERLILIK', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelebilmişler', ['YETERLILIK', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelebileceğim',
#   ['YETERLILIK', 'GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCITEKIL']),
#  ('gelebileceksin', ['YETERLILIK', 'GELECEK', 'IKINCITEKIL']),
#  ('gelebilecek', ['YETERLILIK', 'GELECEK', 'UCUNCUTEKIL']),
#  ('gelebileceğiz',
#   ['YETERLILIK', 'GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCICOGUL']),
#  ('gelebileceksiniz', ['YETERLILIK', 'GELECEK', 'IKINCICOGUL']),
#  ('gelebilecekler', ['YETERLILIK', 'GELECEK', 'UCUNCUCOGUL']),
#  ('gelmeyebilirim',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'BIRINCITEKIL']),
#  ('gelmeyebilirsin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'IKINCITEKIL']),
#  ('gelmeyebilir',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'UCUNCUTEKIL']),
#  ('gelmeyebiliriz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'BIRINCICOGUL']),
#  ('gelmeyebilirsiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'IKINCICOGUL']),
#  ('gelmeyebilirler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'UCUNCUCOGUL']),
#  ('gelmeyebiliyorum',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'BIRINCITEKIL']),
#  ('gelmeyebiliyorsun',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'IKINCITEKIL']),
#  ('gelmeyebiliyor',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'UCUNCUTEKIL']),
#  ('gelmeyebiliyoruz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'BIRINCICOGUL']),
#  ('gelmeyebiliyorsunuz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'IKINCICOGUL']),
#  ('gelmeyebiliyorlar',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'UCUNCUCOGUL']),
#  ('gelmeyebilmekteyim',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL']),
#  ('gelmeyebilmektesin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_MAKTA', 'IKINCITEKIL']),
#  ('gelmeyebilmekte',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL']),
#  ('gelmeyebilmekteyiz',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL']),
#  ('gelmeyebilmektesiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_MAKTA', 'IKINCICOGUL']),
#  ('gelmeyebilmekteler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL']),
#  ('gelmeyebildim',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmeyebildin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelmeyebildi',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelmeyebildik',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmeyebildiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelmeyebildiler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeyebilmişim',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmeyebilmişsin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmeyebilmiş',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmeyebilmişiz',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmeyebilmişsiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmeyebilmişler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeyebileceğim',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL']),
#  ('gelmeyebileceksin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GELECEK', 'IKINCITEKIL']),
#  ('gelmeyebilecek',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GELECEK', 'UCUNCUTEKIL']),
#  ('gelmeyebileceğiz',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL']),
#  ('gelmeyebileceksiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GELECEK', 'IKINCICOGUL']),
#  ('gelmeyebilecekler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GELECEK', 'UCUNCUCOGUL']),
#  ('gelmeliyim', ['GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL']),
#  ('gelmelisin', ['GEREKLILIK', 'IKINCITEKIL']),
#  ('gelmeli', ['GEREKLILIK', 'UCUNCUTEKIL']),
#  ('gelmeliyiz', ['GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL']),
#  ('gelmelisiniz', ['GEREKLILIK', 'IKINCICOGUL']),
#  ('gelmeliler', ['GEREKLILIK', 'UCUNCUCOGUL']),
#  ('gelmemeliyim', ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL']),
#  ('gelmemelisin', ['OLUMSUZLUK', 'GEREKLILIK', 'IKINCITEKIL']),
#  ('gelmemeli', ['OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUTEKIL']),
#  ('gelmemeliyiz', ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL']),
#  ('gelmemelisiniz', ['OLUMSUZLUK', 'GEREKLILIK', 'IKINCICOGUL']),
#  ('gelmemeliler', ['OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUCOGUL']),
#  ('gelsem', ['SARTKIPI', 'BIRINCITEKIL']),
#  ('gelsen', ['SARTKIPI', 'IKINCITEKIL']),
#  ('gelse', ['SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelsek', ['SARTKIPI', 'BIRINCICOGUL']),
#  ('gelseniz', ['SARTKIPI', 'IKINCICOGUL']),
#  ('gelseler', ['SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmesem', ['OLUMSUZLUK', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmesen', ['OLUMSUZLUK', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmese', ['OLUMSUZLUK', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmesek', ['OLUMSUZLUK', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmeseniz', ['OLUMSUZLUK', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmeseler', ['OLUMSUZLUK', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelirsem', ['GENIS', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelirsen', ['GENIS', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelirse', ['GENIS', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelirsek', ['GENIS', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelirseniz', ['GENIS', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelirseler', ['GENIS', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('geliyorsam', ['SIMDIKI_YOR', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('geliyorsan', ['SIMDIKI_YOR', 'SARTKIPI', 'IKINCITEKIL']),
#  ('geliyorsa', ['SIMDIKI_YOR', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('geliyorsak', ['SIMDIKI_YOR', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('geliyorsanız', ['SIMDIKI_YOR', 'SARTKIPI', 'IKINCICOGUL']),
#  ('geliyorsalar', ['SIMDIKI_YOR', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmekteysem',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmekteysen', ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmekteyse', ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmekteysek',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmekteyseniz',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmekteyseler',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('geldiysem', ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('geldiysen', ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL']),
#  ('geldiyse', ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('geldiysek', ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('geldiyseniz', ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL']),
#  ('geldiyseler', ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmişsem', ['DUYULANGECMIS', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmişsen', ['DUYULANGECMIS', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmişse', ['DUYULANGECMIS', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmişsek', ['DUYULANGECMIS', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmişseniz', ['DUYULANGECMIS', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmişseler', ['DUYULANGECMIS', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('geleceksem', ['GELECEK', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('geleceksen', ['GELECEK', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelecekse', ['GELECEK', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('geleceksek', ['GELECEK', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelecekseniz', ['GELECEK', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelecekseler', ['GELECEK', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmezsem', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmezsen', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmezse', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmezsek', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmezseniz', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmezseler', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmiyorsam',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmiyorsan',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmiyorsa',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmiyorsak',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmiyorsanız',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmiyorsalar',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmemekteysem',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmemekteysen',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmemekteyse',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmemekteysek',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmemekteyseniz',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmemekteyseler',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmediysem',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmediysen',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmediyse',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmediysek',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmediyseniz',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmediyseler',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmemişsem', ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmemişsen', ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmemişse', ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmemişsek', ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmemişseniz', ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmemişseler', ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmeyeceksem',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmeyeceksen',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmeyecekse',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmeyeceksek',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmeyecekseniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmeyecekseler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelemem', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'BIRINCITEKIL']),
#  ('gelemezsin', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'IKINCITEKIL']),
#  ('gelemez', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'UCUNCUTEKIL']),
#  ('gelemeyiz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'KAYNASTIRMA', 'BIRINCICOGUL']),
#  ('gelemezsiniz', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'IKINCICOGUL']),
#  ('gelemezler', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'UCUNCUCOGUL']),
#  ('gelemiyorum',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BIRINCITEKIL']),
#  ('gelemiyorsun',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'IKINCITEKIL']),
#  ('gelemiyor',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'UCUNCUTEKIL']),
#  ('gelemiyoruz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BIRINCICOGUL']),
#  ('gelemiyorsunuz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'IKINCICOGUL']),
#  ('gelemiyorlar',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'UCUNCUCOGUL']),
#  ('gelememekteyim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL']),
#  ('gelememektesin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCITEKIL']),
#  ('gelememekte',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL']),
#  ('gelememekteyiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL']),
#  ('gelememektesiniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCICOGUL']),
#  ('gelememekteler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL']),
#  ('gelemedim',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelemedin', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelemedi', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelemedik',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelemediniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelemediler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelememişim',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelememişsin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelememiş', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelememişiz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelememişsiniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelememişler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelemeyeceğim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL']),
#  ('gelemeyeceksin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCITEKIL']),
#  ('gelemeyecek',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUTEKIL']),
#  ('gelemeyeceğiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL']),
#  ('gelemeyeceksiniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCICOGUL']),
#  ('gelemeyecekler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUCOGUL']),
#  ('gelemeyebilirim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'BIRINCITEKIL']),
#  ('gelemeyebilirsin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'IKINCITEKIL']),
#  ('gelemeyebilir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'UCUNCUTEKIL']),
#  ('gelemeyebiliriz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'BIRINCICOGUL']),
#  ('gelemeyebilirsiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'IKINCICOGUL']),
#  ('gelemeyebilirler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'UCUNCUCOGUL']),
#  ('gelemeyebiliyorum',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'BIRINCITEKIL']),
#  ('gelemeyebiliyorsun',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'IKINCITEKIL']),
#  ('gelemeyebiliyor',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'UCUNCUTEKIL']),
#  ('gelemeyebiliyoruz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'BIRINCICOGUL']),
#  ('gelemeyebiliyorsunuz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'IKINCICOGUL']),
#  ('gelemeyebiliyorlar',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'UCUNCUCOGUL']),
#  ('gelemeyebilmekteyim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL']),
#  ('gelemeyebilmektesin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'IKINCITEKIL']),
#  ('gelemeyebilmekte',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'UCUNCUTEKIL']),
#  ('gelemeyebilmekteyiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL']),
#  ('gelemeyebilmektesiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'IKINCICOGUL']),
#  ('gelemeyebilmekteler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'UCUNCUCOGUL']),
#  ('gelemeyebildim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'BIRINCITEKIL']),
#  ('gelemeyebildin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'IKINCITEKIL']),
#  ('gelemeyebildi',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelemeyebildik',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'BIRINCICOGUL']),
#  ('gelemeyebildiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'IKINCICOGUL']),
#  ('gelemeyebildiler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelemeyebilmişim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL']),
#  ('gelemeyebilmişsin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'IKINCITEKIL']),
#  ('gelemeyebilmiş',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelemeyebilmişiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL']),
#  ('gelemeyebilmişsiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'IKINCICOGUL']),
#  ('gelemeyebilmişler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelemeyebileceğim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL']),
#  ('gelemeyebileceksin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'IKINCITEKIL']),
#  ('gelemeyebilecek',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UCUNCUTEKIL']),
#  ('gelemeyebileceğiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL']),
#  ('gelemeyebileceksiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'IKINCICOGUL']),
#  ('gelemeyebilecekler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UCUNCUCOGUL']),
#  ('gelirmişim', ['GENIS', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelirmişsin', ['GENIS', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelirmiş', ['GENIS', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelirmişiz', ['GENIS', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelirmişsiniz', ['GENIS', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelirmişler', ['GENIS', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('geliyormuşum', ['SIMDIKI_YOR', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('geliyormuşsun', ['SIMDIKI_YOR', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('geliyormuş', ['SIMDIKI_YOR', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('geliyormuşuz', ['SIMDIKI_YOR', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('geliyormuşsunuz', ['SIMDIKI_YOR', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('geliyormuşlar', ['SIMDIKI_YOR', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmekteymişim',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmekteymişsin',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmekteymiş',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmekteymişiz',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmekteymişsiniz',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmekteymişler',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('geldiymişim',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('geldiymişsin',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('geldiymiş',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('geldiymişiz',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('geldiymişsiniz',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('geldiymişler',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmişmişim', ['DUYULANGECMIS', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmişmişsin', ['DUYULANGECMIS', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmişmiş', ['DUYULANGECMIS', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmişmişiz', ['DUYULANGECMIS', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmişmişsiniz', ['DUYULANGECMIS', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmişmişler', ['DUYULANGECMIS', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelecekmişim', ['GELECEK', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelecekmişsin', ['GELECEK', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelecekmiş', ['GELECEK', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelecekmişiz', ['GELECEK', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelecekmişsiniz', ['GELECEK', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelecekmişler', ['GELECEK', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmezmişim', ['OLUMSUZLUK', 'GENIS', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmezmişsin', ['OLUMSUZLUK', 'GENIS', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmezmiş', ['OLUMSUZLUK', 'GENIS', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmezmişiz', ['OLUMSUZLUK', 'GENIS', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmezmişsiniz', ['OLUMSUZLUK', 'GENIS', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmezmişler', ['OLUMSUZLUK', 'GENIS', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmiyormuşum',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmiyormuşsun',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'DUYULANGECMIS',
#    'IKINCITEKIL']),
#  ('gelmiyormuş',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelmiyormuşuz',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmiyormuşsunuz',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'DUYULANGECMIS',
#    'IKINCICOGUL']),
#  ('gelmiyormuşlar',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'DUYULANGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelmemekteymişim',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmemekteymişsin',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'IKINCITEKIL']),
#  ('gelmemekteymiş',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelmemekteymişiz',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmemekteymişsiniz',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'IKINCICOGUL']),
#  ('gelmemekteymişler',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelmediymişim',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmediymişsin',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'IKINCITEKIL']),
#  ('gelmediymiş',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelmediymişiz',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmediymişsiniz',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'IKINCICOGUL']),
#  ('gelmediymişler',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelmemişmişim',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmemişmişsin',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmemişmiş',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmemişmişiz',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmemişmişsiniz',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmemişmişler',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeyecekmişim',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmeyecekmişsin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmeyecekmiş',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmeyecekmişiz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmeyecekmişsiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmeyecekmişler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelirdim', ['GENIS', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelirdin', ['GENIS', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelirdi', ['GENIS', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelirdik', ['GENIS', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelirdiniz', ['GENIS', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelirdiler', ['GENIS', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('geliyordum', ['SIMDIKI_YOR', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('geliyordun', ['SIMDIKI_YOR', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('geliyordu', ['SIMDIKI_YOR', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('geliyorduk', ['SIMDIKI_YOR', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('geliyordunuz', ['SIMDIKI_YOR', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('geliyordular', ['SIMDIKI_YOR', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmekteydim',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelmekteydin',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelmekteydi',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelmekteydik',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelmekteydiniz',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelmekteydiler',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('geldiydim',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('geldiydin',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('geldiydi',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('geldiydik',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('geldiydiniz',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('geldiydiler',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmiştim',
#   ['DUYULANGECMIS', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelmiştin',
#   ['DUYULANGECMIS', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelmişti',
#   ['DUYULANGECMIS', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelmiştik',
#   ['DUYULANGECMIS', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelmiştiniz',
#   ['DUYULANGECMIS', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelmiştiler',
#   ['DUYULANGECMIS', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelecektim',
#   ['GELECEK', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelecektin',
#   ['GELECEK', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelecekti',
#   ['GELECEK', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelecektik',
#   ['GELECEK', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelecektiniz',
#   ['GELECEK', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelecektiler',
#   ['GELECEK', 'UNSUZSERTLESMESI', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmezdim', ['OLUMSUZLUK', 'GENIS', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelmezdin', ['OLUMSUZLUK', 'GENIS', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelmezdi', ['OLUMSUZLUK', 'GENIS', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelmezdik', ['OLUMSUZLUK', 'GENIS', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelmezdiniz', ['OLUMSUZLUK', 'GENIS', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelmezdiler', ['OLUMSUZLUK', 'GENIS', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmiyordum',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BILINENGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmiyordun',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BILINENGECMIS',
#    'IKINCITEKIL']),
#  ('gelmiyordu',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelmiyorduk',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BILINENGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmiyordunuz',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BILINENGECMIS',
#    'IKINCICOGUL']),
#  ('gelmiyordular',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelmemekteydim',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmemekteydin',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'IKINCITEKIL']),
#  ('gelmemekteydi',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelmemekteydik',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmemekteydiniz',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'IKINCICOGUL']),
#  ('gelmemekteydiler',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelmediydim',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmediydin',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'IKINCITEKIL']),
#  ('gelmediydi',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelmediydik',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmediydiniz',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'IKINCICOGUL']),
#  ('gelmediydiler',
#   ['OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelmemiştim',
#   ['OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmemiştin',
#   ['OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'IKINCITEKIL']),
#  ('gelmemişti',
#   ['OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelmemiştik',
#   ['OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmemiştiniz',
#   ['OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'IKINCICOGUL']),
#  ('gelmemiştiler',
#   ['OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelmeyecektim',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmeyecektin',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'IKINCITEKIL']),
#  ('gelmeyecekti',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL']),
#  ('gelmeyecektik',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmeyecektiniz',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'IKINCICOGUL']),
#  ('gelmeyecektiler',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZSERTLESMESI',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL']),
#  ('gelseymişim', ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelseymişsin', ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelseymiş', ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelseymişiz', ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelseymişsiniz',
#   ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelseymişler', ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeseymişim',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmeseymişsin',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmeseymiş',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmeseymişiz',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmeseymişsiniz',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmeseymişler',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelseydim', ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelseydin', ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelseydi', ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelseydik', ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelseydiniz', ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelseydiler', ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeseydim',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelmeseydin',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelmeseydi',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelmeseydik',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelmeseydiniz',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelmeseydiler',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeliymişim',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCITEKIL']),
#  ('gelmeliymişsin',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmeliymiş',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmeliymişiz',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCICOGUL']),
#  ('gelmeliymişsiniz',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmeliymişler',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmemeliymişim',
#   ['OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmemeliymişsin',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCITEKIL']),
#  ('gelmemeliymiş',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUTEKIL']),
#  ('gelmemeliymişiz',
#   ['OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmemeliymişsiniz',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCICOGUL']),
#  ('gelmemeliymişler',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeliydim',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL']),
#  ('gelmeliydin',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelmeliydi', ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelmeliydik',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL']),
#  ('gelmeliydiniz',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelmeliydiler',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmemeliydim',
#   ['OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCITEKIL']),
#  ('gelmemeliydin',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL']),
#  ('gelmemeliydi',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL']),
#  ('gelmemeliydik',
#   ['OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCICOGUL']),
#  ('gelmemeliydiniz',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL']),
#  ('gelmemeliydiler',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL']),
#  ('gelmeliysem', ['GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmeliysen', ['GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmeliyse', ['GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmeliysek', ['GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmeliyseniz', ['GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmeliyseler', ['GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('gelmemeliysem',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL']),
#  ('gelmemeliysen',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL']),
#  ('gelmemeliyse',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL']),
#  ('gelmemeliysek',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL']),
#  ('gelmemeliyseniz',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL']),
#  ('gelmemeliyseler',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL']),
#  ('geliyorumdur', ['SIMDIKI_YOR', 'BIRINCITEKIL', 'HABEREDADI']),
#  ('geliyorsundur', ['SIMDIKI_YOR', 'IKINCITEKIL', 'HABEREDADI']),
#  ('geliyordur', ['SIMDIKI_YOR', 'UCUNCUTEKIL', 'HABEREDADI']),
#  ('geliyoruzdur', ['SIMDIKI_YOR', 'BIRINCICOGUL', 'HABEREDADI']),
#  ('geliyorsunuzdur', ['SIMDIKI_YOR', 'IKINCICOGUL', 'HABEREDADI']),
#  ('geliyorlardır', ['SIMDIKI_YOR', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('gelmiyorumdur',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BIRINCITEKIL',
#    'HABEREDADI']),
#  ('gelmiyorsundur',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelmiyordur',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'UCUNCUTEKIL', 'HABEREDADI']),
#  ('gelmiyoruzdur',
#   ['OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BIRINCICOGUL',
#    'HABEREDADI']),
#  ('gelmiyorsunuzdur',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'IKINCICOGUL', 'HABEREDADI']),
#  ('gelmiyorlardır',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('gelmekteyimdir',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL', 'HABEREDADI']),
#  ('gelmektesindir', ['SIMDIKI_MAKTA', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelmektedir', ['SIMDIKI_MAKTA', 'UCUNCUTEKIL', 'HABEREDADI']),
#  ('gelmekteyizdir',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL', 'HABEREDADI']),
#  ('gelmektesinizdir', ['SIMDIKI_MAKTA', 'IKINCICOGUL', 'HABEREDADI']),
#  ('gelmektelerdir', ['SIMDIKI_MAKTA', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('gelmemekteyimdir',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL',
#    'HABEREDADI']),
#  ('gelmemektesindir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelmemektedir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL', 'HABEREDADI']),
#  ('gelmemekteyizdir',
#   ['OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL',
#    'HABEREDADI']),
#  ('gelmemektesinizdir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCICOGUL', 'HABEREDADI']),
#  ('gelmemektelerdir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('gelmişimdir', ['DUYULANGECMIS', 'BIRINCITEKIL', 'HABEREDADI']),
#  ('gelmişsindir', ['DUYULANGECMIS', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelmiştir',
#   ['DUYULANGECMIS', 'UCUNCUTEKIL', 'UNSUZSERTLESMESI', 'HABEREDADI']),
#  ('gelmişizdir', ['DUYULANGECMIS', 'BIRINCICOGUL', 'HABEREDADI']),
#  ('gelmişsinizdir', ['DUYULANGECMIS', 'IKINCICOGUL', 'HABEREDADI']),
#  ('gelmişlerdir', ['DUYULANGECMIS', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('gelmemişimdir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCITEKIL', 'HABEREDADI']),
#  ('gelmemişsindir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelmemiştir',
#   ['OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL',
#    'UNSUZSERTLESMESI',
#    'HABEREDADI']),
#  ('gelmemişizdir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCICOGUL', 'HABEREDADI']),
#  ('gelmemişsinizdir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCICOGUL', 'HABEREDADI']),
#  ('gelmemişlerdir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('geleceğimdir',
#   ['GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCITEKIL', 'HABEREDADI']),
#  ('geleceksindir', ['GELECEK', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelecektir', ['GELECEK', 'UCUNCUTEKIL', 'UNSUZSERTLESMESI', 'HABEREDADI']),
#  ('geleceğizdir',
#   ['GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCICOGUL', 'HABEREDADI']),
#  ('geleceksinizdir', ['GELECEK', 'IKINCICOGUL', 'HABEREDADI']),
#  ('geleceklerdir', ['GELECEK', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('gelmeyeceğimdir',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL',
#    'HABEREDADI']),
#  ('gelmeyeceksindir',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelmeyecektir',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UCUNCUTEKIL',
#    'UNSUZSERTLESMESI',
#    'HABEREDADI']),
#  ('gelmeyeceğizdir',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL',
#    'HABEREDADI']),
#  ('gelmeyeceksinizdir',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCICOGUL', 'HABEREDADI']),
#  ('gelmeyeceklerdir',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('gelmeliyimdir',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL', 'HABEREDADI']),
#  ('gelmelisindir', ['GEREKLILIK', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelmelidir', ['GEREKLILIK', 'UCUNCUTEKIL', 'HABEREDADI']),
#  ('gelmeliyizdir',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL', 'HABEREDADI']),
#  ('gelmelisinizdir', ['GEREKLILIK', 'IKINCICOGUL', 'HABEREDADI']),
#  ('gelmelilerdir', ['GEREKLILIK', 'UCUNCUCOGUL', 'HABEREDADI']),
#  ('gelmemeliyimdir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL', 'HABEREDADI']),
#  ('gelmemelisindir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'IKINCITEKIL', 'HABEREDADI']),
#  ('gelmemelidir', ['OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUTEKIL', 'HABEREDADI']),
#  ('gelmemeliyizdir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL', 'HABEREDADI']),
#  ('gelmemelisinizdir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'IKINCICOGUL', 'HABEREDADI']),
#  ('gelmemelilerdir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUCOGUL', 'HABEREDADI'])]

# %%
len(results)
# Out:
# 564

# %%
VERBS = [w['word'] for w in DICTIONARY if w['type'] == _w.FIIL.value]

# %%
for verb in VERBS:
  w = Word(verb, _w.FIIL)
  w1 = Word(verb, _w.FIIL)
  w2 = Word(verb, _w.FIIL)
  # w.apply_rule(_o.OLUMSUZLUK)
  w.apply_rule(_c.YETERLILIK)
  w.apply_rule(_t.SIMDIKI_YOR)
  w.apply_rule(_p.BIRINCITEKIL)
  print(verb, w.word())
# Out:
# açmak açabiliyorum
# almak alabiliyorum
# anlamak anlayabiliyorum
# aramak arayabiliyorum
# atmak atabiliyorum
# ayırmak ayırabiliyorum
# bakmak bakabiliyorum
# başlamak başlayabiliyorum
# beklemek bekleyebiliyorum
# bilmek bilebiliyorum
# bitmek bitebiliyorum
# bölmek bölebiliyorum
# bulmak bulabiliyorum
# çalışmak çalışabiliyorum
# çarpmak çarpabiliyorum
# çevirmek çevirebiliyorum
# çıkarmak çıkarabiliyorum
# çıkmak çıkabiliyorum
# değişmek değişebiliyorum
# demek diyebiliyorum
# dinlemek dinleyebiliyorum
# doğmak doğabiliyorum
# dönmek dönebiliyorum
# durmak durabiliyorum
# duymak duyabiliyorum
# düşünmek düşünebiliyorum
# eklemek ekleyebiliyorum
# ekmek ekebiliyorum
# etmek edebiliyorum
# evlenmek evlenebiliyorum
# geçmek geçebiliyorum
# gelmek gelebiliyorum
# girmek girebiliyorum
# gitmek gidebiliyorum
# görmek görebiliyorum
# gülmek gülebiliyorum
# hazırlamak hazırlayabiliyorum
# hissetmek hissedebiliyorum
# içmek içebiliyorum
# inanmak inanabiliyorum
# istemek isteyebiliyorum
# izlemek izleyebiliyorum
# kalmak kalabiliyorum
# kapatmak kapatabiliyorum
# katılmak katılabiliyorum
# kazanmak kazanabiliyorum
# kesmek kesebiliyorum
# konuşmak konuşabiliyorum
# kullanmak kullanabiliyorum
# kurmak kurabiliyorum
# kurumak kuruyabiliyorum
# okumak okuyabiliyorum
# olmak olabiliyorum
# oynamak oynayabiliyorum
# öğrenmek öğrenebiliyorum
# ölmek ölebiliyorum
# sağlamak sağlayabiliyorum
# saymak sayabiliyorum
# seçmek seçebiliyorum
# sevmek sevebiliyorum
# seyretmek seyredebiliyorum
# sormak sorabiliyorum
# sürmek sürebiliyorum
# taşımak taşıyabiliyorum
# toplamak toplayabiliyorum
# toplanmak toplanabiliyorum
# tutmak tutabiliyorum
# ulaşmak ulaşabiliyorum
# unutmak unutabiliyorum
# uygulamak uygulayabiliyorum
# uyumak uyuyabiliyorum
# üretmek üretebiliyorum
# varmak varabiliyorum
# vermek verebiliyorum
# vurmak vurabiliyorum
# yakmak yakabiliyorum
# yapmak yapabiliyorum
# yaratmak yaratabiliyorum
# yaşamak yaşayabiliyorum
# yazmak yazabiliyorum
# yemek yiyebiliyorum
# yürümek yürüyebiliyorum
