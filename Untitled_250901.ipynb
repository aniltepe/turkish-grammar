# %%
from enum import Enum
import json
import types

# %%
f = open('rules_250831.json')
RULES = json.load(f)
f = open('dictionary.json')
DICTIONARY = json.load(f)
f = open('sequences_250901.json')
SEQUENCES = json.load(f)

# %%
class _l(Enum): # letter
  SESLI = 1
  SESSIZ = 2
  KALIN = 3
  INCE = 4
  DUZ = 5
  YUVARLAK = 6
  GENIS = 7
  DAR = 8
  SERT = 9
  YUMUSAK = 10
  SUREKLI = 11
  SUREKSIZ = 12
  AKICI = 13
  SIZICI = 14
  KAYNASTIRMA = 15

# %%
class _w(Enum): # word
  ISIM = 1
  FIIL = 2
  SIFAT = 3
  ZARF = 4
  ZAMIR = 5

# %%
class _t(Enum): # tense
  GENIS = 1
  SIMDIKI_YOR = 2
  SIMDIKI_MAKTA = 3
  BILINENGECMIS = 4
  DUYULANGECMIS = 5
  GELECEK = 6

# %%
class _p(Enum): # pronoun
  BIRINCITEKIL = 1
  IKINCITEKIL = 2
  UCUNCUTEKIL = 3
  BIRINCICOGUL = 4
  IKINCICOGUL = 5
  UCUNCUCOGUL = 6

# %%
class _c(Enum): # compound
    BIRLESIKFIIL = 1
    YETERLILIK = 2
    TEZLIK = 3
    SUREKLILIK_DUR = 4
    SUREKLILIK_KAL = 5
    SUREKLILIK_GEL = 6
    YAKLASMA = 7

# %%
class _o(Enum):
    OLUMSUZLUK = 1
    GEREKLILIK = 2
    ISTEKKIPI = 3
    EMIRKIPI = 4
    SARTKIPI = 5
    HABEREDADI = 6

# %%
_a = {
  'a': {'index': 1, 'lower': 'a', 'upper': 'A', 'tags': [_l.SESLI, _l.KALIN, _l.DUZ, _l.GENIS] },
  'b': {'index': 2, 'lower': 'b', 'upper': 'B', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKSIZ] },
  'c': {'index': 3, 'lower': 'c', 'upper': 'C', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKSIZ] },
  'ç': {'index': 4, 'lower': 'ç', 'upper': 'Ç', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKSIZ] },
  'd': {'index': 5, 'lower': 'd', 'upper': 'D', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKSIZ] },
  'e': {'index': 6, 'lower': 'e', 'upper': 'E', 'tags': [_l.SESLI, _l.INCE, _l.DUZ, _l.GENIS] },
  'f': {'index': 7, 'lower': 'f', 'upper': 'F', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKLI] },
  'g': {'index': 8, 'lower': 'g', 'upper': 'G', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKSIZ] },
  'ğ': {'index': 9, 'lower': 'ğ', 'upper': 'Ğ', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'h': {'index': 10, 'lower': 'h', 'upper': 'H', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKLI] },
  'ı': {'index': 11, 'lower': 'ı', 'upper': 'I', 'tags': [_l.SESLI, _l.KALIN, _l.DUZ, _l.DAR] },
  'i': {'index': 12, 'lower': 'i', 'upper': 'İ', 'tags': [_l.SESLI, _l.INCE, _l.DUZ, _l.DAR] },
  'j': {'index': 13, 'lower': 'j', 'upper': 'J', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'k': {'index': 14, 'lower': 'k', 'upper': 'K', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKSIZ] },
  'l': {'index': 15, 'lower': 'l', 'upper': 'L', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'm': {'index': 16, 'lower': 'm', 'upper': 'M', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'n': {'index': 17, 'lower': 'n', 'upper': 'N', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI, _l.KAYNASTIRMA] },
  'o': {'index': 18, 'lower': 'o', 'upper': 'O', 'tags': [_l.SESLI, _l.KALIN, _l.YUVARLAK, _l.GENIS] },
  'ö': {'index': 19, 'lower': 'ö', 'upper': 'Ö', 'tags': [_l.SESLI, _l.INCE, _l.YUVARLAK, _l.GENIS] },
  'p': {'index': 20, 'lower': 'p', 'upper': 'P', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKSIZ] },
  'r': {'index': 21, 'lower': 'r', 'upper': 'R', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  's': {'index': 22, 'lower': 's', 'upper': 'S', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKLI, _l.KAYNASTIRMA] },
  'ş': {'index': 23, 'lower': 'ş', 'upper': 'Ş', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKLI, _l.KAYNASTIRMA] },
  't': {'index': 24, 'lower': 't', 'upper': 'T', 'tags': [_l.SESSIZ, _l.SERT, _l.SUREKSIZ] },
  'u': {'index': 25, 'lower': 'u', 'upper': 'U', 'tags': [_l.SESLI, _l.KALIN, _l.YUVARLAK, _l.DAR] },
  'ü': {'index': 26, 'lower': 'ü', 'upper': 'Ü', 'tags': [_l.SESLI, _l.INCE, _l.YUVARLAK, _l.DAR] },
  'v': {'index': 27, 'lower': 'v', 'upper': 'V', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] },
  'y': {'index': 28, 'lower': 'y', 'upper': 'Y', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI, _l.KAYNASTIRMA] },
  'z': {'index': 29, 'lower': 'z', 'upper': 'Z', 'tags': [_l.SESSIZ, _l.YUMUSAK, _l.SUREKLI] }
}

# %%
def FIND_LETTERS(tags):
  return [_a[l] for l in _a if all(t in _a[l]['tags'] for t in tags)]

# %%
def CHECK_LETTER(letter, tags):
    return all(t in letter['tags'] for t in tags)

# %%
def REPLACE_TAGS(tags, old, new):
    return [t if t != old else new for t in tags]

# %%
class Word:
  def __init__(self, word, type=None):
    self.root = word
    if type == _w.FIIL:
      self.root = word[:-3]
    self.letters, self.vowels, self.consonants = self.set_letters(self.root)
    self.default = word
    self.type = type

    self.applied = []
    self.ambiguous = False

    self.next_word = None
    self.prev_word = None
    self.punct_after = None
  
  def word(self, type='lower'):
    w = (''.join([l['upper'] for l in self.letters]) if type == 'upper'
         else ''.join([l['upper'] if i == 0 else l['lower'] for i, l in enumerate(self.letters)]) if type == 'pascal' 
         else ''.join([l['lower'] for l in self.letters]))
    return w

  def append(self, suffix, code, prev_suffix=None):
    # print(''.join([l['lower'] for l in suffix]))
    self._suffix = (suffix, code)
    if len(suffix) > 0:
      ns = types.SimpleNamespace()
      setattr(ns, 'name', '_APPEND')
      self.apply_rule(ns)
      count = len(self.letters)
      self.letters.extend(self._suffix[0])
      self.vowels.extend([dict(l, **{'w_idx': count + i}) for i, l in enumerate(self._suffix[0]) if _l.SESLI in l['tags']])
      self.consonants.extend([dict(l, **{'w_idx': count + i}) for i, l in enumerate(self._suffix[0]) if _l.SESSIZ in l['tags']])
    self.applied.append({'code': code, 'type': 'append', 'field1': self._suffix[0]})
    self._suffix = prev_suffix
    
  def replace(self, idx, new, code):
    old = self.letters[idx]
    self.letters = [l if i != idx else new for i, l in enumerate(self.letters)]
    if _l.SESLI in new['tags']:
      self.vowels = [l if l['w_idx'] != idx else dict(new, **{'w_idx': idx}) for l in self.vowels]
    elif _l.SESSIZ in new['tags']:
      self.consonants = [l if l['w_idx'] != idx else dict(new, **{'w_idx': idx}) for l in self.consonants]
    self.applied.append({'code': code, 'type': 'replace', 'field1': (old, idx), 'field2': new})
  
  def replace_suffix(self, idx, new, code):
    old = self._suffix[0][idx]
    self._suffix = ([l if i != idx else new for i, l in enumerate(self._suffix[0])], self._suffix[1])
    self.applied.append({'code': code, 'type': 'replace', 'field1': (old, len(self.letters) + idx), 'field2': new})

  def apply_rule(self, type):
    rules = [r for r in RULES if r['type'] == type.name]
    var_match = {
      'self': self,
      '_l': _l,
      '_w': _w,
      '_a': _a,
      'CHECK_LETTER': CHECK_LETTER,
      'FIND_LETTERS': FIND_LETTERS,
      'REPLACE_TAGS': REPLACE_TAGS
    }
    for rule in rules:
      if 'if' not in rule or eval(' and '.join(rule['if']), var_match):
        # print(rule['id'])
        for do in rule['do']:
          eval(do, var_match)
        break

  def check_applied(self, codes, type, idx=None):
    if idx == None:
      return (all(t in [a['code'] for a in self.applied] for t in codes) if type == 'allin'
              else all(t not in [a['code'] for a in self.applied] for t in codes) if type == 'allnotin'
              else any(t in [a['code'] for a in self.applied] for t in codes) if type == 'anyin'
              else any(t not in [a['code'] for a in self.applied] for t in codes) if type == 'anynotin'
              else not(any(t in [a['code'] for a in self.applied] for t in codes)) if type == 'notanyin'
              else None)
    if (idx < 0 and idx * -1 > len(self.applied)) or (idx >= 0 and idx >= len(self.applied)):
      return True if type == 'notin' else False if type == 'in' else None
    return (self.applied[idx]['code'] in codes if type == 'in'
            else self.applied[idx]['code'] not in codes if type == 'notin'
            else None)

  def clone(self, cloneid=""):
    w_new = Word('')
    w_new.letters = self.letters[:]
    w_new.vowels = self.vowels[:]
    w_new.consonants = self.consonants[:]
    w_new.applied = self.applied[:]
    w_new.type = self.type
    w_new.default = self.default
    w_new.root = self.root
    w_new.cloneid = cloneid
    return w_new
  
  @staticmethod
  def set_letters(word):
    letters = [_a[l] for l in Word.lower(word)]
    vowels = [dict(_a[l], **{'w_idx': i}) for i, l in enumerate(Word.lower(word)) if _l.SESLI in _a[l]['tags']]
    consonants = [dict(_a[l], **{'w_idx': i}) for i, l in enumerate(Word.lower(word)) if _l.SESSIZ in _a[l]['tags']]
    return letters, vowels, consonants
  
  @staticmethod
  def lower(word):
    return word.replace('İ','i').replace('I','ı').lower()
  
  @staticmethod
  def upper(word):
    return word.replace('i','İ').upper()

# %%
class Sentence:
    def __init__(self, sentence):
        self.words = [Word(w) for w in sentence.split(' ')]
        self.punctuation = None

# %%
TEST_PARAGRAPH = 'Çalışma hayatına dahil edilen çocuklar oyun oynama, öğrenme, hayal kurma ve dinlenme gibi temel ihtiyaçlardan mahrum bırakılmaktadır. Çalışan çocuklar, çocukluklarını yaşayamamanın ötesinde ağır ve sağlıksız çalışma koşulları nedeniyle bedensel, ruhsal ve sosyal anlamda zarar görme tehlikesiyle karşı karşıya kalmaktadır. Aslında hemen hemen her evde belirli bir yaşın üzerindeki çocuklar ev işlerinde çalışırlar. Bu çalışma kimi zaman küçük bir kardeşin bakımı veya evin derlenip toparlanması, kimi zaman da tarla ve bahçe işlerine yardım etme şeklinde olabilir. Bunlar genellikle yarı zamanlı, belirli bir zamanlaması olmayan, o andaki ihtiyaca göre şekillenen geçici işlerdir. Oysa çalışan çocuk kavramı ile çocuğun kendi evinin dışında başkasının işinde veya kendi ailesinin işinde üretime doğrudan katkı sağlayacak şekilde çalışması kastedilmektedir.'

# %%
TEST_SENTENCE = 'Bilirsin.'

# %%
set([r["type"] for r in RULES])
# Out:
# {'BILINENGECMIS',
#  'BIRINCICOGUL',
#  'BIRINCITEKIL',
#  'BIRLESIKFIIL',
#  'DUYULANGECMIS',
#  'GELECEK',
#  'GENIS',
#  'GEREKLILIK',
#  'HABEREDADI',
#  'IKINCICOGUL',
#  'IKINCITEKIL',
#  'MASTAR',
#  'OLUMSUZLUK',
#  'SARTKIPI',
#  'SIMDIKI_MAKTA',
#  'SIMDIKI_YOR',
#  'TEZLIK',
#  'UCUNCUCOGUL',
#  'UCUNCUTEKIL',
#  'YETERLILIK',
#  '_APPEND'}

# %%
w1 = Word('gelmek', _w.FIIL)
results = []
var_match = {'_w': _w, '_t': _t, '_c': _c, '_p': _p, '_o': _o}
for SEQUENCE in SEQUENCES:
    w_root = w1.clone()
    word_build = [[w_root]]
    for sequence in SEQUENCE['seq']:
        rules = sequence if isinstance(sequence, list) else [sequence]
        possibles = []
        separator = ";"
        for rule in rules:
            if rule == "_":
                for last_possible in word_build[-1]:
                    possibles.append(last_possible.clone())
                continue
            if separator in rule:
                obj = rule
            else:
                obj = eval(rule, var_match)

            for last_possible in word_build[-1]:
                if type(obj) == type(Enum):
                    for i in obj:
                        w_new = last_possible.clone(SEQUENCE["id"])
                        w_new.apply_rule(i)
                        possibles.append(w_new)
                elif type(type(obj)) == type(Enum):
                    w_new = last_possible.clone(SEQUENCE["id"])
                    w_new.apply_rule(obj)
                    possibles.append(w_new)
                else:
                    w_new = last_possible.clone(SEQUENCE["id"])
                    serial_rules = obj.split(separator)
                    for sr in serial_rules:
                        sr_obj = eval(sr.strip(), var_match)
                        w_new.apply_rule(sr_obj)
                    possibles.append(w_new)

        word_build.append(possibles)
        print([w.word() for w in possibles])

    # print([_.word() for w in word_build for _ in w])
    for all_possible in word_build[-1]:
        possible = (all_possible.word(), [a['code'] for a in all_possible.applied], all_possible.cloneid)
        results.append(possible)
        # if possible not in results:
        #     results.append(possible)
        # else:
        #     print(possible, "already in the list")
results
# Out:
# ['gel', 'gelme', 'geleme']
# ['gel', 'gelme', 'geleme', 'gelebil', 'gelmeyebil', 'gelemeyebil']
# ['gelir', 'geliyor', 'gelmekte', 'geldi', 'gelmiş', 'gelecek', 'gelme', 'gelmiyor', 'gelmemekte', 'gelmedi', 'gelmemiş', 'gelmeyecek', 'geleme', 'gelemiyor', 'gelememekte', 'gelemedi', 'gelememiş', 'gelemeyecek', 'gelebilir', 'gelebiliyor', 'gelebilmekte', 'gelebildi', 'gelebilmiş', 'gelebilecek', 'gelmeyebilir', 'gelmeyebiliyor', 'gelmeyebilmekte', 'gelmeyebildi', 'gelmeyebilmiş', 'gelmeyebilecek', 'gelemeyebilir', 'gelemeyebiliyor', 'gelemeyebilmekte', 'gelemeyebildi', 'gelemeyebilmiş', 'gelemeyebilecek']
# ['gelirim', 'gelirsin', 'gelir', 'geliriz', 'gelirsiniz', 'gelirler', 'geliyorum', 'geliyorsun', 'geliyor', 'geliyoruz', 'geliyorsunuz', 'geliyorlar', 'gelmekteyim', 'gelmektesin', 'gelmekte', 'gelmekteyiz', 'gelmektesiniz', 'gelmekteler', 'geldim', 'geldin', 'geldi', 'geldik', 'geldiniz', 'geldiler', 'gelmişim', 'gelmişsin', 'gelmiş', 'gelmişiz', 'gelmişsiniz', 'gelmişler', 'geleceğim', 'geleceksin', 'gelecek', 'geleceğiz', 'geleceksiniz', 'gelecekler', 'gelmem', 'gelmezsin', 'gelmez', 'gelmeyiz', 'gelmezsiniz', 'gelmezler', 'gelmiyorum', 'gelmiyorsun', 'gelmiyor', 'gelmiyoruz', 'gelmiyorsunuz', 'gelmiyorlar', 'gelmemekteyim', 'gelmemektesin', 'gelmemekte', 'gelmemekteyiz', 'gelmemektesiniz', 'gelmemekteler', 'gelmedim', 'gelmedin', 'gelmedi', 'gelmedik', 'gelmediniz', 'gelmediler', 'gelmemişim', 'gelmemişsin', 'gelmemiş', 'gelmemişiz', 'gelmemişsiniz', 'gelmemişler', 'gelmeyeceğim', 'gelmeyeceksin', 'gelmeyecek', 'gelmeyeceğiz', 'gelmeyeceksiniz', 'gelmeyecekler', 'gelemem', 'gelemezsin', 'gelemez', 'gelemeyiz', 'gelemezsiniz', 'gelemezler', 'gelemiyorum', 'gelemiyorsun', 'gelemiyor', 'gelemiyoruz', 'gelemiyorsunuz', 'gelemiyorlar', 'gelememekteyim', 'gelememektesin', 'gelememekte', 'gelememekteyiz', 'gelememektesiniz', 'gelememekteler', 'gelemedim', 'gelemedin', 'gelemedi', 'gelemedik', 'gelemediniz', 'gelemediler', 'gelememişim', 'gelememişsin', 'gelememiş', 'gelememişiz', 'gelememişsiniz', 'gelememişler', 'gelemeyeceğim', 'gelemeyeceksin', 'gelemeyecek', 'gelemeyeceğiz', 'gelemeyeceksiniz', 'gelemeyecekler', 'gelebilirim', 'gelebilirsin', 'gelebilir', 'gelebiliriz', 'gelebilirsiniz', 'gelebilirler', 'gelebiliyorum', 'gelebiliyorsun', 'gelebiliyor', 'gelebiliyoruz', 'gelebiliyorsunuz', 'gelebiliyorlar', 'gelebilmekteyim', 'gelebilmektesin', 'gelebilmekte', 'gelebilmekteyiz', 'gelebilmektesiniz', 'gelebilmekteler', 'gelebildim', 'gelebildin', 'gelebildi', 'gelebildik', 'gelebildiniz', 'gelebildiler', 'gelebilmişim', 'gelebilmişsin', 'gelebilmiş', 'gelebilmişiz', 'gelebilmişsiniz', 'gelebilmişler', 'gelebileceğim', 'gelebileceksin', 'gelebilecek', 'gelebileceğiz', 'gelebileceksiniz', 'gelebilecekler', 'gelmeyebilirim', 'gelmeyebilirsin', 'gelmeyebilir', 'gelmeyebiliriz', 'gelmeyebilirsiniz', 'gelmeyebilirler', 'gelmeyebiliyorum', 'gelmeyebiliyorsun', 'gelmeyebiliyor', 'gelmeyebiliyoruz', 'gelmeyebiliyorsunuz', 'gelmeyebiliyorlar', 'gelmeyebilmekteyim', 'gelmeyebilmektesin', 'gelmeyebilmekte', 'gelmeyebilmekteyiz', 'gelmeyebilmektesiniz', 'gelmeyebilmekteler', 'gelmeyebildim', 'gelmeyebildin', 'gelmeyebildi', 'gelmeyebildik', 'gelmeyebildiniz', 'gelmeyebildiler', 'gelmeyebilmişim', 'gelmeyebilmişsin', 'gelmeyebilmiş', 'gelmeyebilmişiz', 'gelmeyebilmişsiniz', 'gelmeyebilmişler', 'gelmeyebileceğim', 'gelmeyebileceksin', 'gelmeyebilecek', 'gelmeyebileceğiz', 'gelmeyebileceksiniz', 'gelmeyebilecekler', 'gelemeyebilirim', 'gelemeyebilirsin', 'gelemeyebilir', 'gelemeyebiliriz', 'gelemeyebilirsiniz', 'gelemeyebilirler', 'gelemeyebiliyorum', 'gelemeyebiliyorsun', 'gelemeyebiliyor', 'gelemeyebiliyoruz', 'gelemeyebiliyorsunuz', 'gelemeyebiliyorlar', 'gelemeyebilmekteyim', 'gelemeyebilmektesin', 'gelemeyebilmekte', 'gelemeyebilmekteyiz', 'gelemeyebilmektesiniz', 'gelemeyebilmekteler', 'gelemeyebildim', 'gelemeyebildin', 'gelemeyebildi', 'gelemeyebildik', 'gelemeyebildiniz', 'gelemeyebildiler', 'gelemeyebilmişim', 'gelemeyebilmişsin', 'gelemeyebilmiş', 'gelemeyebilmişiz', 'gelemeyebilmişsiniz', 'gelemeyebilmişler', 'gelemeyebileceğim', 'gelemeyebileceksin', 'gelemeyebilecek', 'gelemeyebileceğiz', 'gelemeyebileceksiniz', 'gelemeyebilecekler']
# ['gel', 'gelme', 'geleme']
# ['gelmeli', 'gelmemeli', 'gelememeli', 'gelse', 'gelmese', 'gelemese']
# ['gelmeliyim', 'gelmelisin', 'gelmeli', 'gelmeliyiz', 'gelmelisiniz', 'gelmeliler', 'gelmemeliyim', 'gelmemelisin', 'gelmemeli', 'gelmemeliyiz', 'gelmemelisiniz', 'gelmemeliler', 'gelememeliyim', 'gelememelisin', 'gelememeli', 'gelememeliyiz', 'gelememelisiniz', 'gelememeliler', 'gelsem', 'gelsen', 'gelse', 'gelsek', 'gelseniz', 'gelseler', 'gelmesem', 'gelmesen', 'gelmese', 'gelmesek', 'gelmeseniz', 'gelmeseler', 'gelemesem', 'gelemesen', 'gelemese', 'gelemesek', 'gelemeseniz', 'gelemeseler']
# ['gel', 'gelme', 'geleme']
# ['gelir', 'geliyor', 'gelmekte', 'geldi', 'gelmiş', 'gelecek', 'gelme', 'gelmiyor', 'gelmemekte', 'gelmedi', 'gelmemiş', 'gelmeyecek', 'geleme', 'gelemiyor', 'gelememekte', 'gelemedi', 'gelememiş', 'gelemeyecek', 'gelmeli', 'gelmemeli', 'gelememeli']
# ['gelirse', 'geliyorsa', 'gelmekteyse', 'geldiyse', 'gelmişse', 'gelecekse', 'gelmezse', 'gelmiyorsa', 'gelmemekteyse', 'gelmediyse', 'gelmemişse', 'gelmeyecekse', 'gelemezse', 'gelemiyorsa', 'gelememekteyse', 'gelemediyse', 'gelememişse', 'gelemeyecekse', 'gelmeliyse', 'gelmemeliyse', 'gelememeliyse', 'gelirmiş', 'geliyormuş', 'gelmekteymiş', 'geldiymiş', 'gelmişmiş', 'gelecekmiş', 'gelmezmiş', 'gelmiyormuş', 'gelmemekteymiş', 'gelmediymiş', 'gelmemişmiş', 'gelmeyecekmiş', 'gelemezmiş', 'gelemiyormuş', 'gelememekteymiş', 'gelemediymiş', 'gelememişmiş', 'gelemeyecekmiş', 'gelmeliymiş', 'gelmemeliymiş', 'gelememeliymiş', 'gelirdi', 'geliyordu', 'gelmekteydi', 'geldiydi', 'gelmişti', 'gelecekti', 'gelmezdi', 'gelmiyordu', 'gelmemekteydi', 'gelmediydi', 'gelmemişti', 'gelmeyecekti', 'gelemezdi', 'gelemiyordu', 'gelememekteydi', 'gelemediydi', 'gelememişti', 'gelemeyecekti', 'gelmeliydi', 'gelmemeliydi', 'gelememeliydi']
# ['gelirsem', 'gelirsen', 'gelirse', 'gelirsek', 'gelirseniz', 'gelirseler', 'geliyorsam', 'geliyorsan', 'geliyorsa', 'geliyorsak', 'geliyorsanız', 'geliyorsalar', 'gelmekteysem', 'gelmekteysen', 'gelmekteyse', 'gelmekteysek', 'gelmekteyseniz', 'gelmekteyseler', 'geldiysem', 'geldiysen', 'geldiyse', 'geldiysek', 'geldiyseniz', 'geldiyseler', 'gelmişsem', 'gelmişsen', 'gelmişse', 'gelmişsek', 'gelmişseniz', 'gelmişseler', 'geleceksem', 'geleceksen', 'gelecekse', 'geleceksek', 'gelecekseniz', 'gelecekseler', 'gelmezsem', 'gelmezsen', 'gelmezse', 'gelmezsek', 'gelmezseniz', 'gelmezseler', 'gelmiyorsam', 'gelmiyorsan', 'gelmiyorsa', 'gelmiyorsak', 'gelmiyorsanız', 'gelmiyorsalar', 'gelmemekteysem', 'gelmemekteysen', 'gelmemekteyse', 'gelmemekteysek', 'gelmemekteyseniz', 'gelmemekteyseler', 'gelmediysem', 'gelmediysen', 'gelmediyse', 'gelmediysek', 'gelmediyseniz', 'gelmediyseler', 'gelmemişsem', 'gelmemişsen', 'gelmemişse', 'gelmemişsek', 'gelmemişseniz', 'gelmemişseler', 'gelmeyeceksem', 'gelmeyeceksen', 'gelmeyecekse', 'gelmeyeceksek', 'gelmeyecekseniz', 'gelmeyecekseler', 'gelemezsem', 'gelemezsen', 'gelemezse', 'gelemezsek', 'gelemezseniz', 'gelemezseler', 'gelemiyorsam', 'gelemiyorsan', 'gelemiyorsa', 'gelemiyorsak', 'gelemiyorsanız', 'gelemiyorsalar', 'gelememekteysem', 'gelememekteysen', 'gelememekteyse', 'gelememekteysek', 'gelememekteyseniz', 'gelememekteyseler', 'gelemediysem', 'gelemediysen', 'gelemediyse', 'gelemediysek', 'gelemediyseniz', 'gelemediyseler', 'gelememişsem', 'gelememişsen', 'gelememişse', 'gelememişsek', 'gelememişseniz', 'gelememişseler', 'gelemeyeceksem', 'gelemeyeceksen', 'gelemeyecekse', 'gelemeyeceksek', 'gelemeyecekseniz', 'gelemeyecekseler', 'gelmeliysem', 'gelmeliysen', 'gelmeliyse', 'gelmeliysek', 'gelmeliyseniz', 'gelmeliyseler', 'gelmemeliysem', 'gelmemeliysen', 'gelmemeliyse', 'gelmemeliysek', 'gelmemeliyseniz', 'gelmemeliyseler', 'gelememeliysem', 'gelememeliysen', 'gelememeliyse', 'gelememeliysek', 'gelememeliyseniz', 'gelememeliyseler', 'gelirmişim', 'gelirmişsin', 'gelirmiş', 'gelirmişiz', 'gelirmişsiniz', 'gelirmişler', 'geliyormuşum', 'geliyormuşsun', 'geliyormuş', 'geliyormuşuz', 'geliyormuşsunuz', 'geliyormuşlar', 'gelmekteymişim', 'gelmekteymişsin', 'gelmekteymiş', 'gelmekteymişiz', 'gelmekteymişsiniz', 'gelmekteymişler', 'geldiymişim', 'geldiymişsin', 'geldiymiş', 'geldiymişiz', 'geldiymişsiniz', 'geldiymişler', 'gelmişmişim', 'gelmişmişsin', 'gelmişmiş', 'gelmişmişiz', 'gelmişmişsiniz', 'gelmişmişler', 'gelecekmişim', 'gelecekmişsin', 'gelecekmiş', 'gelecekmişiz', 'gelecekmişsiniz', 'gelecekmişler', 'gelmezmişim', 'gelmezmişsin', 'gelmezmiş', 'gelmezmişiz', 'gelmezmişsiniz', 'gelmezmişler', 'gelmiyormuşum', 'gelmiyormuşsun', 'gelmiyormuş', 'gelmiyormuşuz', 'gelmiyormuşsunuz', 'gelmiyormuşlar', 'gelmemekteymişim', 'gelmemekteymişsin', 'gelmemekteymiş', 'gelmemekteymişiz', 'gelmemekteymişsiniz', 'gelmemekteymişler', 'gelmediymişim', 'gelmediymişsin', 'gelmediymiş', 'gelmediymişiz', 'gelmediymişsiniz', 'gelmediymişler', 'gelmemişmişim', 'gelmemişmişsin', 'gelmemişmiş', 'gelmemişmişiz', 'gelmemişmişsiniz', 'gelmemişmişler', 'gelmeyecekmişim', 'gelmeyecekmişsin', 'gelmeyecekmiş', 'gelmeyecekmişiz', 'gelmeyecekmişsiniz', 'gelmeyecekmişler', 'gelemezmişim', 'gelemezmişsin', 'gelemezmiş', 'gelemezmişiz', 'gelemezmişsiniz', 'gelemezmişler', 'gelemiyormuşum', 'gelemiyormuşsun', 'gelemiyormuş', 'gelemiyormuşuz', 'gelemiyormuşsunuz', 'gelemiyormuşlar', 'gelememekteymişim', 'gelememekteymişsin', 'gelememekteymiş', 'gelememekteymişiz', 'gelememekteymişsiniz', 'gelememekteymişler', 'gelemediymişim', 'gelemediymişsin', 'gelemediymiş', 'gelemediymişiz', 'gelemediymişsiniz', 'gelemediymişler', 'gelememişmişim', 'gelememişmişsin', 'gelememişmiş', 'gelememişmişiz', 'gelememişmişsiniz', 'gelememişmişler', 'gelemeyecekmişim', 'gelemeyecekmişsin', 'gelemeyecekmiş', 'gelemeyecekmişiz', 'gelemeyecekmişsiniz', 'gelemeyecekmişler', 'gelmeliymişim', 'gelmeliymişsin', 'gelmeliymiş', 'gelmeliymişiz', 'gelmeliymi ...
# ['gel', 'gelme', 'geleme']
# ['gelse', 'gelmese', 'gelemese']
# ['gelseymiş', 'gelmeseymiş', 'gelemeseymiş', 'gelseydi', 'gelmeseydi', 'gelemeseydi']
# ['gelseymişim', 'gelseymişsin', 'gelseymiş', 'gelseymişiz', 'gelseymişsiniz', 'gelseymişler', 'gelmeseymişim', 'gelmeseymişsin', 'gelmeseymiş', 'gelmeseymişiz', 'gelmeseymişsiniz', 'gelmeseymişler', 'gelemeseymişim', 'gelemeseymişsin', 'gelemeseymiş', 'gelemeseymişiz', 'gelemeseymişsiniz', 'gelemeseymişler', 'gelseydim', 'gelseydin', 'gelseydi', 'gelseydik', 'gelseydiniz', 'gelseydiler', 'gelmeseydim', 'gelmeseydin', 'gelmeseydi', 'gelmeseydik', 'gelmeseydiniz', 'gelmeseydiler', 'gelemeseydim', 'gelemeseydin', 'gelemeseydi', 'gelemeseydik', 'gelemeseydiniz', 'gelemeseydiler']
# ['gel', 'gelme', 'geleme']
# ['geliyor', 'gelmiyor', 'gelemiyor', 'gelmekte', 'gelmemekte', 'gelememekte', 'gelmiş', 'gelmemiş', 'gelememiş', 'gelecek', 'gelmeyecek', 'gelemeyecek', 'gelmeli', 'gelmemeli', 'gelememeli']
# ['geliyorum', 'geliyorsun', 'geliyor', 'geliyoruz', 'geliyorsunuz', 'geliyorlar', 'gelmiyorum', 'gelmiyorsun', 'gelmiyor', 'gelmiyoruz', 'gelmiyorsunuz', 'gelmiyorlar', 'gelemiyorum', 'gelemiyorsun', 'gelemiyor', 'gelemiyoruz', 'gelemiyorsunuz', 'gelemiyorlar', 'gelmekteyim', 'gelmektesin', 'gelmekte', 'gelmekteyiz', 'gelmektesiniz', 'gelmekteler', 'gelmemekteyim', 'gelmemektesin', 'gelmemekte', 'gelmemekteyiz', 'gelmemektesiniz', 'gelmemekteler', 'gelememekteyim', 'gelememektesin', 'gelememekte', 'gelememekteyiz', 'gelememektesiniz', 'gelememekteler', 'gelmişim', 'gelmişsin', 'gelmiş', 'gelmişiz', 'gelmişsiniz', 'gelmişler', 'gelmemişim', 'gelmemişsin', 'gelmemiş', 'gelmemişiz', 'gelmemişsiniz', 'gelmemişler', 'gelememişim', 'gelememişsin', 'gelememiş', 'gelememişiz', 'gelememişsiniz', 'gelememişler', 'geleceğim', 'geleceksin', 'gelecek', 'geleceğiz', 'geleceksiniz', 'gelecekler', 'gelmeyeceğim', 'gelmeyeceksin', 'gelmeyecek', 'gelmeyeceğiz', 'gelmeyeceksiniz', 'gelmeyecekler', 'gelemeyeceğim', 'gelemeyeceksin', 'gelemeyecek', 'gelemeyeceğiz', 'gelemeyeceksiniz', 'gelemeyecekler', 'gelmeliyim', 'gelmelisin', 'gelmeli', 'gelmeliyiz', 'gelmelisiniz', 'gelmeliler', 'gelmemeliyim', 'gelmemelisin', 'gelmemeli', 'gelmemeliyiz', 'gelmemelisiniz', 'gelmemeliler', 'gelememeliyim', 'gelememelisin', 'gelememeli', 'gelememeliyiz', 'gelememelisiniz', 'gelememeliler']
# ['geliyorumdur', 'geliyorsundur', 'geliyordur', 'geliyoruzdur', 'geliyorsunuzdur', 'geliyorlardır', 'gelmiyorumdur', 'gelmiyorsundur', 'gelmiyordur', 'gelmiyoruzdur', 'gelmiyorsunuzdur', 'gelmiyorlardır', 'gelemiyorumdur', 'gelemiyorsundur', 'gelemiyordur', 'gelemiyoruzdur', 'gelemiyorsunuzdur', 'gelemiyorlardır', 'gelmekteyimdir', 'gelmektesindir', 'gelmektedir', 'gelmekteyizdir', 'gelmektesinizdir', 'gelmektelerdir', 'gelmemekteyimdir', 'gelmemektesindir', 'gelmemektedir', 'gelmemekteyizdir', 'gelmemektesinizdir', 'gelmemektelerdir', 'gelememekteyimdir', 'gelememektesindir', 'gelememektedir', 'gelememekteyizdir', 'gelememektesinizdir', 'gelememektelerdir', 'gelmişimdir', 'gelmişsindir', 'gelmiştir', 'gelmişizdir', 'gelmişsinizdir', 'gelmişlerdir', 'gelmemişimdir', 'gelmemişsindir', 'gelmemiştir', 'gelmemişizdir', 'gelmemişsinizdir', 'gelmemişlerdir', 'gelememişimdir', 'gelememişsindir', 'gelememiştir', 'gelememişizdir', 'gelememişsinizdir', 'gelememişlerdir', 'geleceğimdir', 'geleceksindir', 'gelecektir', 'geleceğizdir', 'geleceksinizdir', 'geleceklerdir', 'gelmeyeceğimdir', 'gelmeyeceksindir', 'gelmeyecektir', 'gelmeyeceğizdir', 'gelmeyeceksinizdir', 'gelmeyeceklerdir', 'gelemeyeceğimdir', 'gelemeyeceksindir', 'gelemeyecektir', 'gelemeyeceğizdir', 'gelemeyeceksinizdir', 'gelemeyeceklerdir', 'gelmeliyimdir', 'gelmelisindir', 'gelmelidir', 'gelmeliyizdir', 'gelmelisinizdir', 'gelmelilerdir', 'gelmemeliyimdir', 'gelmemelisindir', 'gelmemelidir', 'gelmemeliyizdir', 'gelmemelisinizdir', 'gelmemelilerdir', 'gelememeliyimdir', 'gelememelisindir', 'gelememelidir', 'gelememeliyizdir', 'gelememelisinizdir', 'gelememelilerdir']
# [('gelirim', ['GENIS', 'BIRINCITEKIL'], 'seq001'),
#  ('gelirsin', ['GENIS', 'IKINCITEKIL'], 'seq001'),
#  ('gelir', ['GENIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('geliriz', ['GENIS', 'BIRINCICOGUL'], 'seq001'),
#  ('gelirsiniz', ['GENIS', 'IKINCICOGUL'], 'seq001'),
#  ('gelirler', ['GENIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('geliyorum', ['SIMDIKI_YOR', 'BIRINCITEKIL'], 'seq001'),
#  ('geliyorsun', ['SIMDIKI_YOR', 'IKINCITEKIL'], 'seq001'),
#  ('geliyor', ['SIMDIKI_YOR', 'UCUNCUTEKIL'], 'seq001'),
#  ('geliyoruz', ['SIMDIKI_YOR', 'BIRINCICOGUL'], 'seq001'),
#  ('geliyorsunuz', ['SIMDIKI_YOR', 'IKINCICOGUL'], 'seq001'),
#  ('geliyorlar', ['SIMDIKI_YOR', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelmekteyim', ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL'], 'seq001'),
#  ('gelmektesin', ['SIMDIKI_MAKTA', 'IKINCITEKIL'], 'seq001'),
#  ('gelmekte', ['SIMDIKI_MAKTA', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelmekteyiz', ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL'], 'seq001'),
#  ('gelmektesiniz', ['SIMDIKI_MAKTA', 'IKINCICOGUL'], 'seq001'),
#  ('gelmekteler', ['SIMDIKI_MAKTA', 'UCUNCUCOGUL'], 'seq001'),
#  ('geldim', ['BILINENGECMIS', 'BIRINCITEKIL'], 'seq001'),
#  ('geldin', ['BILINENGECMIS', 'IKINCITEKIL'], 'seq001'),
#  ('geldi', ['BILINENGECMIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('geldik', ['BILINENGECMIS', 'BIRINCICOGUL'], 'seq001'),
#  ('geldiniz', ['BILINENGECMIS', 'IKINCICOGUL'], 'seq001'),
#  ('geldiler', ['BILINENGECMIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelmişim', ['DUYULANGECMIS', 'BIRINCITEKIL'], 'seq001'),
#  ('gelmişsin', ['DUYULANGECMIS', 'IKINCITEKIL'], 'seq001'),
#  ('gelmiş', ['DUYULANGECMIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelmişiz', ['DUYULANGECMIS', 'BIRINCICOGUL'], 'seq001'),
#  ('gelmişsiniz', ['DUYULANGECMIS', 'IKINCICOGUL'], 'seq001'),
#  ('gelmişler', ['DUYULANGECMIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('geleceğim', ['GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCITEKIL'], 'seq001'),
#  ('geleceksin', ['GELECEK', 'IKINCITEKIL'], 'seq001'),
#  ('gelecek', ['GELECEK', 'UCUNCUTEKIL'], 'seq001'),
#  ('geleceğiz', ['GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCICOGUL'], 'seq001'),
#  ('geleceksiniz', ['GELECEK', 'IKINCICOGUL'], 'seq001'),
#  ('gelecekler', ['GELECEK', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelmem', ['OLUMSUZLUK', 'GENIS', 'BIRINCITEKIL'], 'seq001'),
#  ('gelmezsin', ['OLUMSUZLUK', 'GENIS', 'IKINCITEKIL'], 'seq001'),
#  ('gelmez', ['OLUMSUZLUK', 'GENIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelmeyiz',
#   ['OLUMSUZLUK', 'GENIS', 'KAYNASTIRMA', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmezsiniz', ['OLUMSUZLUK', 'GENIS', 'IKINCICOGUL'], 'seq001'),
#  ('gelmezler', ['OLUMSUZLUK', 'GENIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelmiyorum',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmiyorsun',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelmiyor',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelmiyoruz',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmiyorsunuz',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelmiyorlar',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelmemekteyim',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmemektesin', ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCITEKIL'], 'seq001'),
#  ('gelmemekte', ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelmemekteyiz',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmemektesiniz', ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCICOGUL'], 'seq001'),
#  ('gelmemekteler', ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelmedim', ['OLUMSUZLUK', 'BILINENGECMIS', 'BIRINCITEKIL'], 'seq001'),
#  ('gelmedin', ['OLUMSUZLUK', 'BILINENGECMIS', 'IKINCITEKIL'], 'seq001'),
#  ('gelmedi', ['OLUMSUZLUK', 'BILINENGECMIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelmedik', ['OLUMSUZLUK', 'BILINENGECMIS', 'BIRINCICOGUL'], 'seq001'),
#  ('gelmediniz', ['OLUMSUZLUK', 'BILINENGECMIS', 'IKINCICOGUL'], 'seq001'),
#  ('gelmediler', ['OLUMSUZLUK', 'BILINENGECMIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelmemişim', ['OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCITEKIL'], 'seq001'),
#  ('gelmemişsin', ['OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCITEKIL'], 'seq001'),
#  ('gelmemiş', ['OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelmemişiz', ['OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCICOGUL'], 'seq001'),
#  ('gelmemişsiniz', ['OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCICOGUL'], 'seq001'),
#  ('gelmemişler', ['OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelmeyeceğim',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmeyeceksin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelmeyecek',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelmeyeceğiz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmeyeceksiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelmeyecekler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemem',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemezsin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelemez', ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelemeyiz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'KAYNASTIRMA', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemezsiniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelemezler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemiyorum',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemiyorsun',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'IKINCITEKIL'],
#   'seq001'),
#  ('gelemiyor',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemiyoruz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemiyorsunuz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'IKINCICOGUL'],
#   'seq001'),
#  ('gelemiyorlar',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelememekteyim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelememektesin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelememekte',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelememekteyiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelememektesiniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelememekteler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemedim',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemedin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelemedi',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemedik',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemediniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelemediler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'BILINENGECMIS', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelememişim',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelememişsin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelememiş',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelememişiz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelememişsiniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelememişler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemeyeceğim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemeyeceksin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelemeyecek',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemeyeceğiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemeyeceksiniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelemeyecekler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelebilirim', ['YETERLILIK', 'GENIS', 'BIRINCITEKIL'], 'seq001'),
#  ('gelebilirsin', ['YETERLILIK', 'GENIS', 'IKINCITEKIL'], 'seq001'),
#  ('gelebilir', ['YETERLILIK', 'GENIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelebiliriz', ['YETERLILIK', 'GENIS', 'BIRINCICOGUL'], 'seq001'),
#  ('gelebilirsiniz', ['YETERLILIK', 'GENIS', 'IKINCICOGUL'], 'seq001'),
#  ('gelebilirler', ['YETERLILIK', 'GENIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelebiliyorum', ['YETERLILIK', 'SIMDIKI_YOR', 'BIRINCITEKIL'], 'seq001'),
#  ('gelebiliyorsun', ['YETERLILIK', 'SIMDIKI_YOR', 'IKINCITEKIL'], 'seq001'),
#  ('gelebiliyor', ['YETERLILIK', 'SIMDIKI_YOR', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelebiliyoruz', ['YETERLILIK', 'SIMDIKI_YOR', 'BIRINCICOGUL'], 'seq001'),
#  ('gelebiliyorsunuz', ['YETERLILIK', 'SIMDIKI_YOR', 'IKINCICOGUL'], 'seq001'),
#  ('gelebiliyorlar', ['YETERLILIK', 'SIMDIKI_YOR', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelebilmekteyim',
#   ['YETERLILIK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelebilmektesin', ['YETERLILIK', 'SIMDIKI_MAKTA', 'IKINCITEKIL'], 'seq001'),
#  ('gelebilmekte', ['YETERLILIK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelebilmekteyiz',
#   ['YETERLILIK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelebilmektesiniz',
#   ['YETERLILIK', 'SIMDIKI_MAKTA', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelebilmekteler', ['YETERLILIK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelebildim', ['YETERLILIK', 'BILINENGECMIS', 'BIRINCITEKIL'], 'seq001'),
#  ('gelebildin', ['YETERLILIK', 'BILINENGECMIS', 'IKINCITEKIL'], 'seq001'),
#  ('gelebildi', ['YETERLILIK', 'BILINENGECMIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelebildik', ['YETERLILIK', 'BILINENGECMIS', 'BIRINCICOGUL'], 'seq001'),
#  ('gelebildiniz', ['YETERLILIK', 'BILINENGECMIS', 'IKINCICOGUL'], 'seq001'),
#  ('gelebildiler', ['YETERLILIK', 'BILINENGECMIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelebilmişim', ['YETERLILIK', 'DUYULANGECMIS', 'BIRINCITEKIL'], 'seq001'),
#  ('gelebilmişsin', ['YETERLILIK', 'DUYULANGECMIS', 'IKINCITEKIL'], 'seq001'),
#  ('gelebilmiş', ['YETERLILIK', 'DUYULANGECMIS', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelebilmişiz', ['YETERLILIK', 'DUYULANGECMIS', 'BIRINCICOGUL'], 'seq001'),
#  ('gelebilmişsiniz', ['YETERLILIK', 'DUYULANGECMIS', 'IKINCICOGUL'], 'seq001'),
#  ('gelebilmişler', ['YETERLILIK', 'DUYULANGECMIS', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelebileceğim',
#   ['YETERLILIK', 'GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelebileceksin', ['YETERLILIK', 'GELECEK', 'IKINCITEKIL'], 'seq001'),
#  ('gelebilecek', ['YETERLILIK', 'GELECEK', 'UCUNCUTEKIL'], 'seq001'),
#  ('gelebileceğiz',
#   ['YETERLILIK', 'GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelebileceksiniz', ['YETERLILIK', 'GELECEK', 'IKINCICOGUL'], 'seq001'),
#  ('gelebilecekler', ['YETERLILIK', 'GELECEK', 'UCUNCUCOGUL'], 'seq001'),
#  ('gelmeyebilirim',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmeyebilirsin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelmeyebilir',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelmeyebiliriz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmeyebilirsiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelmeyebilirler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GENIS', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelmeyebiliyorum',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmeyebiliyorsun',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelmeyebiliyor',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelmeyebiliyoruz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmeyebiliyorsunuz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelmeyebiliyorlar',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_YOR', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelmeyebilmekteyim',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmeyebilmektesin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_MAKTA', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelmeyebilmekte',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelmeyebilmekteyiz',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmeyebilmektesiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_MAKTA', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelmeyebilmekteler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelmeyebildim',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmeyebildin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelmeyebildi',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelmeyebildik',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmeyebildiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelmeyebildiler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'BILINENGECMIS', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelmeyebilmişim',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmeyebilmişsin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelmeyebilmiş',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelmeyebilmişiz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmeyebilmişsiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelmeyebilmişler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'DUYULANGECMIS', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelmeyebileceğim',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelmeyebileceksin',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GELECEK', 'IKINCITEKIL'],
#   'seq001'),
#  ('gelmeyebilecek',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GELECEK', 'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelmeyebileceğiz',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelmeyebileceksiniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GELECEK', 'IKINCICOGUL'],
#   'seq001'),
#  ('gelmeyebilecekler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'YETERLILIK', 'GELECEK', 'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemeyebilirim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemeyebilirsin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'IKINCITEKIL'],
#   'seq001'),
#  ('gelemeyebilir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemeyebiliriz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemeyebilirsiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'IKINCICOGUL'],
#   'seq001'),
#  ('gelemeyebilirler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GENIS',
#    'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemeyebiliyorum',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemeyebiliyorsun',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'IKINCITEKIL'],
#   'seq001'),
#  ('gelemeyebiliyor',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemeyebiliyoruz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemeyebiliyorsunuz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'IKINCICOGUL'],
#   'seq001'),
#  ('gelemeyebiliyorlar',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_YOR',
#    'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemeyebilmekteyim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemeyebilmektesin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'IKINCITEKIL'],
#   'seq001'),
#  ('gelemeyebilmekte',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemeyebilmekteyiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemeyebilmektesiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'IKINCICOGUL'],
#   'seq001'),
#  ('gelemeyebilmekteler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'SIMDIKI_MAKTA',
#    'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemeyebildim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemeyebildin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'IKINCITEKIL'],
#   'seq001'),
#  ('gelemeyebildi',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemeyebildik',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemeyebildiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'IKINCICOGUL'],
#   'seq001'),
#  ('gelemeyebildiler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemeyebilmişim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemeyebilmişsin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'IKINCITEKIL'],
#   'seq001'),
#  ('gelemeyebilmiş',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemeyebilmişiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemeyebilmişsiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'IKINCICOGUL'],
#   'seq001'),
#  ('gelemeyebilmişler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'DUYULANGECMIS',
#    'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelemeyebileceğim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL'],
#   'seq001'),
#  ('gelemeyebileceksin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'IKINCITEKIL'],
#   'seq001'),
#  ('gelemeyebilecek',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UCUNCUTEKIL'],
#   'seq001'),
#  ('gelemeyebileceğiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL'],
#   'seq001'),
#  ('gelemeyebileceksiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'IKINCICOGUL'],
#   'seq001'),
#  ('gelemeyebilecekler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'YETERLILIK',
#    'GELECEK',
#    'UCUNCUCOGUL'],
#   'seq001'),
#  ('gelmeliyim', ['GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL'], 'seq002'),
#  ('gelmelisin', ['GEREKLILIK', 'IKINCITEKIL'], 'seq002'),
#  ('gelmeli', ['GEREKLILIK', 'UCUNCUTEKIL'], 'seq002'),
#  ('gelmeliyiz', ['GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL'], 'seq002'),
#  ('gelmelisiniz', ['GEREKLILIK', 'IKINCICOGUL'], 'seq002'),
#  ('gelmeliler', ['GEREKLILIK', 'UCUNCUCOGUL'], 'seq002'),
#  ('gelmemeliyim',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL'],
#   'seq002'),
#  ('gelmemelisin', ['OLUMSUZLUK', 'GEREKLILIK', 'IKINCITEKIL'], 'seq002'),
#  ('gelmemeli', ['OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUTEKIL'], 'seq002'),
#  ('gelmemeliyiz',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL'],
#   'seq002'),
#  ('gelmemelisiniz', ['OLUMSUZLUK', 'GEREKLILIK', 'IKINCICOGUL'], 'seq002'),
#  ('gelmemeliler', ['OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUCOGUL'], 'seq002'),
#  ('gelememeliyim',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL'],
#   'seq002'),
#  ('gelememelisin',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'IKINCITEKIL'],
#   'seq002'),
#  ('gelememeli',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUTEKIL'],
#   'seq002'),
#  ('gelememeliyiz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL'],
#   'seq002'),
#  ('gelememelisiniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'IKINCICOGUL'],
#   'seq002'),
#  ('gelememeliler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUCOGUL'],
#   'seq002'),
#  ('gelsem', ['SARTKIPI', 'BIRINCITEKIL'], 'seq002'),
#  ('gelsen', ['SARTKIPI', 'IKINCITEKIL'], 'seq002'),
#  ('gelse', ['SARTKIPI', 'UCUNCUTEKIL'], 'seq002'),
#  ('gelsek', ['SARTKIPI', 'BIRINCICOGUL'], 'seq002'),
#  ('gelseniz', ['SARTKIPI', 'IKINCICOGUL'], 'seq002'),
#  ('gelseler', ['SARTKIPI', 'UCUNCUCOGUL'], 'seq002'),
#  ('gelmesem', ['OLUMSUZLUK', 'SARTKIPI', 'BIRINCITEKIL'], 'seq002'),
#  ('gelmesen', ['OLUMSUZLUK', 'SARTKIPI', 'IKINCITEKIL'], 'seq002'),
#  ('gelmese', ['OLUMSUZLUK', 'SARTKIPI', 'UCUNCUTEKIL'], 'seq002'),
#  ('gelmesek', ['OLUMSUZLUK', 'SARTKIPI', 'BIRINCICOGUL'], 'seq002'),
#  ('gelmeseniz', ['OLUMSUZLUK', 'SARTKIPI', 'IKINCICOGUL'], 'seq002'),
#  ('gelmeseler', ['OLUMSUZLUK', 'SARTKIPI', 'UCUNCUCOGUL'], 'seq002'),
#  ('gelemesem',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq002'),
#  ('gelemesen',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq002'),
#  ('gelemese',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq002'),
#  ('gelemesek',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq002'),
#  ('gelemeseniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq002'),
#  ('gelemeseler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq002'),
#  ('gelirsem', ['GENIS', 'SARTKIPI', 'BIRINCITEKIL'], 'seq003'),
#  ('gelirsen', ['GENIS', 'SARTKIPI', 'IKINCITEKIL'], 'seq003'),
#  ('gelirse', ['GENIS', 'SARTKIPI', 'UCUNCUTEKIL'], 'seq003'),
#  ('gelirsek', ['GENIS', 'SARTKIPI', 'BIRINCICOGUL'], 'seq003'),
#  ('gelirseniz', ['GENIS', 'SARTKIPI', 'IKINCICOGUL'], 'seq003'),
#  ('gelirseler', ['GENIS', 'SARTKIPI', 'UCUNCUCOGUL'], 'seq003'),
#  ('geliyorsam', ['SIMDIKI_YOR', 'SARTKIPI', 'BIRINCITEKIL'], 'seq003'),
#  ('geliyorsan', ['SIMDIKI_YOR', 'SARTKIPI', 'IKINCITEKIL'], 'seq003'),
#  ('geliyorsa', ['SIMDIKI_YOR', 'SARTKIPI', 'UCUNCUTEKIL'], 'seq003'),
#  ('geliyorsak', ['SIMDIKI_YOR', 'SARTKIPI', 'BIRINCICOGUL'], 'seq003'),
#  ('geliyorsanız', ['SIMDIKI_YOR', 'SARTKIPI', 'IKINCICOGUL'], 'seq003'),
#  ('geliyorsalar', ['SIMDIKI_YOR', 'SARTKIPI', 'UCUNCUCOGUL'], 'seq003'),
#  ('gelmekteysem',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelmekteysen',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelmekteyse',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelmekteysek',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelmekteyseniz',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelmekteyseler',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('geldiysem',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('geldiysen',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('geldiyse',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('geldiysek',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('geldiyseniz',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('geldiyseler',
#   ['BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelmişsem', ['DUYULANGECMIS', 'SARTKIPI', 'BIRINCITEKIL'], 'seq003'),
#  ('gelmişsen', ['DUYULANGECMIS', 'SARTKIPI', 'IKINCITEKIL'], 'seq003'),
#  ('gelmişse', ['DUYULANGECMIS', 'SARTKIPI', 'UCUNCUTEKIL'], 'seq003'),
#  ('gelmişsek', ['DUYULANGECMIS', 'SARTKIPI', 'BIRINCICOGUL'], 'seq003'),
#  ('gelmişseniz', ['DUYULANGECMIS', 'SARTKIPI', 'IKINCICOGUL'], 'seq003'),
#  ('gelmişseler', ['DUYULANGECMIS', 'SARTKIPI', 'UCUNCUCOGUL'], 'seq003'),
#  ('geleceksem', ['GELECEK', 'SARTKIPI', 'BIRINCITEKIL'], 'seq003'),
#  ('geleceksen', ['GELECEK', 'SARTKIPI', 'IKINCITEKIL'], 'seq003'),
#  ('gelecekse', ['GELECEK', 'SARTKIPI', 'UCUNCUTEKIL'], 'seq003'),
#  ('geleceksek', ['GELECEK', 'SARTKIPI', 'BIRINCICOGUL'], 'seq003'),
#  ('gelecekseniz', ['GELECEK', 'SARTKIPI', 'IKINCICOGUL'], 'seq003'),
#  ('gelecekseler', ['GELECEK', 'SARTKIPI', 'UCUNCUCOGUL'], 'seq003'),
#  ('gelmezsem', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'BIRINCITEKIL'], 'seq003'),
#  ('gelmezsen', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'IKINCITEKIL'], 'seq003'),
#  ('gelmezse', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'UCUNCUTEKIL'], 'seq003'),
#  ('gelmezsek', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'BIRINCICOGUL'], 'seq003'),
#  ('gelmezseniz', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'IKINCICOGUL'], 'seq003'),
#  ('gelmezseler', ['OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'UCUNCUCOGUL'], 'seq003'),
#  ('gelmiyorsam',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelmiyorsan',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelmiyorsa',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelmiyorsak',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelmiyorsanız',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelmiyorsalar',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelmemekteysem',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelmemekteysen',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelmemekteyse',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelmemekteysek',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelmemekteyseniz',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelmemekteyseler',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelmediysem',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelmediysen',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelmediyse',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelmediysek',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelmediyseniz',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelmediyseler',
#   ['OLUMSUZLUK', 'BILINENGECMIS', 'KAYNASTIRMA', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelmemişsem',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelmemişsen',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelmemişse',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelmemişsek',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelmemişseniz',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelmemişseler',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelmeyeceksem',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelmeyeceksen',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelmeyecekse',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelmeyeceksek',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelmeyecekseniz',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelmeyecekseler',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelemezsem',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelemezsen',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelemezse',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelemezsek',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelemezseniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelemezseler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GENIS', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelemiyorsam',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'SARTKIPI',
#    'BIRINCITEKIL'],
#   'seq003'),
#  ('gelemiyorsan',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'SARTKIPI',
#    'IKINCITEKIL'],
#   'seq003'),
#  ('gelemiyorsa',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'SARTKIPI',
#    'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelemiyorsak',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'SARTKIPI',
#    'BIRINCICOGUL'],
#   'seq003'),
#  ('gelemiyorsanız',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'SARTKIPI',
#    'IKINCICOGUL'],
#   'seq003'),
#  ('gelemiyorsalar',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'SARTKIPI',
#    'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelememekteysem',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'BIRINCITEKIL'],
#   'seq003'),
#  ('gelememekteysen',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'IKINCITEKIL'],
#   'seq003'),
#  ('gelememekteyse',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelememekteysek',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'BIRINCICOGUL'],
#   'seq003'),
#  ('gelememekteyseniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'IKINCICOGUL'],
#   'seq003'),
#  ('gelememekteyseler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelemediysem',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'BIRINCITEKIL'],
#   'seq003'),
#  ('gelemediysen',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'IKINCITEKIL'],
#   'seq003'),
#  ('gelemediyse',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelemediysek',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'BIRINCICOGUL'],
#   'seq003'),
#  ('gelemediyseniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'IKINCICOGUL'],
#   'seq003'),
#  ('gelemediyseler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'BILINENGECMIS',
#    'KAYNASTIRMA',
#    'SARTKIPI',
#    'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelememişsem',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelememişsen',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelememişse',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelememişsek',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelememişseniz',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelememişseler',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'SARTKIPI', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelemeyeceksem',
# ...
#    'BILINENGECMIS',
#    'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelmeliydim',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelmeliydin',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelmeliydi',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelmeliydik',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelmeliydiniz',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelmeliydiler',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelmemeliydim',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL'],
#   'seq003'),
#  ('gelmemeliydin',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL'],
#   'seq003'),
#  ('gelmemeliydi',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelmemeliydik',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL'],
#   'seq003'),
#  ('gelmemeliydiniz',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL'],
#   'seq003'),
#  ('gelmemeliydiler',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelememeliydim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCITEKIL'],
#   'seq003'),
#  ('gelememeliydin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'IKINCITEKIL'],
#   'seq003'),
#  ('gelememeliydi',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL'],
#   'seq003'),
#  ('gelememeliydik',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCICOGUL'],
#   'seq003'),
#  ('gelememeliydiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'IKINCICOGUL'],
#   'seq003'),
#  ('gelememeliydiler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL'],
#   'seq003'),
#  ('gelseymişim',
#   ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCITEKIL'],
#   'seq004'),
#  ('gelseymişsin',
#   ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCITEKIL'],
#   'seq004'),
#  ('gelseymiş',
#   ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUTEKIL'],
#   'seq004'),
#  ('gelseymişiz',
#   ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCICOGUL'],
#   'seq004'),
#  ('gelseymişsiniz',
#   ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCICOGUL'],
#   'seq004'),
#  ('gelseymişler',
#   ['SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUCOGUL'],
#   'seq004'),
#  ('gelmeseymişim',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCITEKIL'],
#   'seq004'),
#  ('gelmeseymişsin',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCITEKIL'],
#   'seq004'),
#  ('gelmeseymiş',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUTEKIL'],
#   'seq004'),
#  ('gelmeseymişiz',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'BIRINCICOGUL'],
#   'seq004'),
#  ('gelmeseymişsiniz',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'IKINCICOGUL'],
#   'seq004'),
#  ('gelmeseymişler',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'DUYULANGECMIS', 'UCUNCUCOGUL'],
#   'seq004'),
#  ('gelemeseymişim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL'],
#   'seq004'),
#  ('gelemeseymişsin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'IKINCITEKIL'],
#   'seq004'),
#  ('gelemeseymiş',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL'],
#   'seq004'),
#  ('gelemeseymişiz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL'],
#   'seq004'),
#  ('gelemeseymişsiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'IKINCICOGUL'],
#   'seq004'),
#  ('gelemeseymişler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'DUYULANGECMIS',
#    'UCUNCUCOGUL'],
#   'seq004'),
#  ('gelseydim',
#   ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL'],
#   'seq004'),
#  ('gelseydin',
#   ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL'],
#   'seq004'),
#  ('gelseydi',
#   ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL'],
#   'seq004'),
#  ('gelseydik',
#   ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL'],
#   'seq004'),
#  ('gelseydiniz',
#   ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL'],
#   'seq004'),
#  ('gelseydiler',
#   ['SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL'],
#   'seq004'),
#  ('gelmeseydim',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCITEKIL'],
#   'seq004'),
#  ('gelmeseydin',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCITEKIL'],
#   'seq004'),
#  ('gelmeseydi',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUTEKIL'],
#   'seq004'),
#  ('gelmeseydik',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'BIRINCICOGUL'],
#   'seq004'),
#  ('gelmeseydiniz',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'IKINCICOGUL'],
#   'seq004'),
#  ('gelmeseydiler',
#   ['OLUMSUZLUK', 'SARTKIPI', 'KAYNASTIRMA', 'BILINENGECMIS', 'UCUNCUCOGUL'],
#   'seq004'),
#  ('gelemeseydim',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCITEKIL'],
#   'seq004'),
#  ('gelemeseydin',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'IKINCITEKIL'],
#   'seq004'),
#  ('gelemeseydi',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'UCUNCUTEKIL'],
#   'seq004'),
#  ('gelemeseydik',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'BIRINCICOGUL'],
#   'seq004'),
#  ('gelemeseydiniz',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'IKINCICOGUL'],
#   'seq004'),
#  ('gelemeseydiler',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SARTKIPI',
#    'KAYNASTIRMA',
#    'BILINENGECMIS',
#    'UCUNCUCOGUL'],
#   'seq004'),
#  ('geliyorumdur', ['SIMDIKI_YOR', 'BIRINCITEKIL', 'HABEREDADI'], 'seq005'),
#  ('geliyorsundur', ['SIMDIKI_YOR', 'IKINCITEKIL', 'HABEREDADI'], 'seq005'),
#  ('geliyordur', ['SIMDIKI_YOR', 'UCUNCUTEKIL', 'HABEREDADI'], 'seq005'),
#  ('geliyoruzdur', ['SIMDIKI_YOR', 'BIRINCICOGUL', 'HABEREDADI'], 'seq005'),
#  ('geliyorsunuzdur', ['SIMDIKI_YOR', 'IKINCICOGUL', 'HABEREDADI'], 'seq005'),
#  ('geliyorlardır', ['SIMDIKI_YOR', 'UCUNCUCOGUL', 'HABEREDADI'], 'seq005'),
#  ('gelmiyorumdur',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'BIRINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmiyorsundur',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'IKINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmiyordur',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'UCUNCUTEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmiyoruzdur',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'BIRINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmiyorsunuzdur',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmiyorlardır',
#   ['OLUMSUZLUK', 'UNLUDARALMASI', 'SIMDIKI_YOR', 'UCUNCUCOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelemiyorumdur',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BIRINCITEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemiyorsundur',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'IKINCITEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemiyordur',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'UCUNCUTEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemiyoruzdur',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'BIRINCICOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemiyorsunuzdur',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'IKINCICOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemiyorlardır',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'UNLUDARALMASI',
#    'SIMDIKI_YOR',
#    'UCUNCUCOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelmekteyimdir',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmektesindir', ['SIMDIKI_MAKTA', 'IKINCITEKIL', 'HABEREDADI'], 'seq005'),
#  ('gelmektedir', ['SIMDIKI_MAKTA', 'UCUNCUTEKIL', 'HABEREDADI'], 'seq005'),
#  ('gelmekteyizdir',
#   ['SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmektesinizdir',
#   ['SIMDIKI_MAKTA', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmektelerdir', ['SIMDIKI_MAKTA', 'UCUNCUCOGUL', 'HABEREDADI'], 'seq005'),
#  ('gelmemekteyimdir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemektesindir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemektedir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemekteyizdir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'KAYNASTIRMA', 'BIRINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemektesinizdir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemektelerdir',
#   ['OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememekteyimdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelememektesindir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememektedir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUTEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememekteyizdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'SIMDIKI_MAKTA',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelememektesinizdir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememektelerdir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'SIMDIKI_MAKTA', 'UCUNCUCOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmişimdir', ['DUYULANGECMIS', 'BIRINCITEKIL', 'HABEREDADI'], 'seq005'),
#  ('gelmişsindir', ['DUYULANGECMIS', 'IKINCITEKIL', 'HABEREDADI'], 'seq005'),
#  ('gelmiştir',
#   ['DUYULANGECMIS', 'UCUNCUTEKIL', 'UNSUZSERTLESMESI', 'HABEREDADI'],
#   'seq005'),
#  ('gelmişizdir', ['DUYULANGECMIS', 'BIRINCICOGUL', 'HABEREDADI'], 'seq005'),
#  ('gelmişsinizdir', ['DUYULANGECMIS', 'IKINCICOGUL', 'HABEREDADI'], 'seq005'),
#  ('gelmişlerdir', ['DUYULANGECMIS', 'UCUNCUCOGUL', 'HABEREDADI'], 'seq005'),
#  ('gelmemişimdir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemişsindir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemiştir',
#   ['OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL',
#    'UNSUZSERTLESMESI',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelmemişizdir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'BIRINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemişsinizdir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemişlerdir',
#   ['OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUCOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememişimdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'BIRINCITEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelememişsindir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememiştir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'UCUNCUTEKIL',
#    'UNSUZSERTLESMESI',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelememişizdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'DUYULANGECMIS',
#    'BIRINCICOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelememişsinizdir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememişlerdir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'DUYULANGECMIS', 'UCUNCUCOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('geleceğimdir',
#   ['GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('geleceksindir', ['GELECEK', 'IKINCITEKIL', 'HABEREDADI'], 'seq005'),
#  ('gelecektir',
#   ['GELECEK', 'UCUNCUTEKIL', 'UNSUZSERTLESMESI', 'HABEREDADI'],
#   'seq005'),
#  ('geleceğizdir',
#   ['GELECEK', 'UNSUZYUMUSAMASI', 'BIRINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('geleceksinizdir', ['GELECEK', 'IKINCICOGUL', 'HABEREDADI'], 'seq005'),
#  ('geleceklerdir', ['GELECEK', 'UCUNCUCOGUL', 'HABEREDADI'], 'seq005'),
#  ('gelmeyeceğimdir',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelmeyeceksindir',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmeyecektir',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UCUNCUTEKIL',
#    'UNSUZSERTLESMESI',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelmeyeceğizdir',
#   ['OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelmeyeceksinizdir',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmeyeceklerdir',
#   ['OLUMSUZLUK', 'KAYNASTIRMA', 'GELECEK', 'UCUNCUCOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelemeyeceğimdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCITEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemeyeceksindir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'IKINCITEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemeyecektir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UCUNCUTEKIL',
#    'UNSUZSERTLESMESI',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemeyeceğizdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UNSUZYUMUSAMASI',
#    'BIRINCICOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemeyeceksinizdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'IKINCICOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelemeyeceklerdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'KAYNASTIRMA',
#    'GELECEK',
#    'UCUNCUCOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelmeliyimdir',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmelisindir', ['GEREKLILIK', 'IKINCITEKIL', 'HABEREDADI'], 'seq005'),
#  ('gelmelidir', ['GEREKLILIK', 'UCUNCUTEKIL', 'HABEREDADI'], 'seq005'),
#  ('gelmeliyizdir',
#   ['GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmelisinizdir', ['GEREKLILIK', 'IKINCICOGUL', 'HABEREDADI'], 'seq005'),
#  ('gelmelilerdir', ['GEREKLILIK', 'UCUNCUCOGUL', 'HABEREDADI'], 'seq005'),
#  ('gelmemeliyimdir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemelisindir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'IKINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemelidir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUTEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemeliyizdir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'KAYNASTIRMA', 'BIRINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemelisinizdir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelmemelilerdir',
#   ['OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUCOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememeliyimdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BIRINCITEKIL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelememelisindir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'IKINCITEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememelidir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUTEKIL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememeliyizdir',
#   ['BIRLESIKFIIL',
#    'OLUMSUZLUK',
#    'GEREKLILIK',
#    'KAYNASTIRMA',
#    'BIRINCICOGUL',
#    'HABEREDADI'],
#   'seq005'),
#  ('gelememelisinizdir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'IKINCICOGUL', 'HABEREDADI'],
#   'seq005'),
#  ('gelememelilerdir',
#   ['BIRLESIKFIIL', 'OLUMSUZLUK', 'GEREKLILIK', 'UCUNCUCOGUL', 'HABEREDADI'],
#   'seq005')]

# %%
len(results)
# Out:
# 756

# %%
VERBS = [w['word'] for w in DICTIONARY if w['type'] == _w.FIIL.value]

# %%
for verb in VERBS:
  w = Word(verb, _w.FIIL)
  w1 = Word(verb, _w.FIIL)
  w2 = Word(verb, _w.FIIL)
  # w.apply_rule(_o.OLUMSUZLUK)
  w.apply_rule(_c.YETERLILIK)
  w.apply_rule(_t.SIMDIKI_YOR)
  w.apply_rule(_p.BIRINCITEKIL)
  print(verb, w.word())
# Out:
# açmak açabiliyorum
# almak alabiliyorum
# anlamak anlayabiliyorum
# aramak arayabiliyorum
# atmak atabiliyorum
# ayırmak ayırabiliyorum
# bakmak bakabiliyorum
# başlamak başlayabiliyorum
# beklemek bekleyebiliyorum
# bilmek bilebiliyorum
# bitmek bitebiliyorum
# bölmek bölebiliyorum
# bulmak bulabiliyorum
# çalışmak çalışabiliyorum
# çarpmak çarpabiliyorum
# çevirmek çevirebiliyorum
# çıkarmak çıkarabiliyorum
# çıkmak çıkabiliyorum
# değişmek değişebiliyorum
# demek diyebiliyorum
# dinlemek dinleyebiliyorum
# doğmak doğabiliyorum
# dönmek dönebiliyorum
# durmak durabiliyorum
# duymak duyabiliyorum
# düşünmek düşünebiliyorum
# eklemek ekleyebiliyorum
# ekmek ekebiliyorum
# etmek edebiliyorum
# evlenmek evlenebiliyorum
# geçmek geçebiliyorum
# gelmek gelebiliyorum
# girmek girebiliyorum
# gitmek gidebiliyorum
# görmek görebiliyorum
# gülmek gülebiliyorum
# hazırlamak hazırlayabiliyorum
# hissetmek hissedebiliyorum
# içmek içebiliyorum
# inanmak inanabiliyorum
# istemek isteyebiliyorum
# izlemek izleyebiliyorum
# kalmak kalabiliyorum
# kapatmak kapatabiliyorum
# katılmak katılabiliyorum
# kazanmak kazanabiliyorum
# kesmek kesebiliyorum
# konuşmak konuşabiliyorum
# kullanmak kullanabiliyorum
# kurmak kurabiliyorum
# kurumak kuruyabiliyorum
# okumak okuyabiliyorum
# olmak olabiliyorum
# oynamak oynayabiliyorum
# öğrenmek öğrenebiliyorum
# ölmek ölebiliyorum
# sağlamak sağlayabiliyorum
# saymak sayabiliyorum
# seçmek seçebiliyorum
# sevmek sevebiliyorum
# seyretmek seyredebiliyorum
# sormak sorabiliyorum
# sürmek sürebiliyorum
# taşımak taşıyabiliyorum
# toplamak toplayabiliyorum
# toplanmak toplanabiliyorum
# tutmak tutabiliyorum
# ulaşmak ulaşabiliyorum
# unutmak unutabiliyorum
# uygulamak uygulayabiliyorum
# uyumak uyuyabiliyorum
# üretmek üretebiliyorum
# varmak varabiliyorum
# vermek verebiliyorum
# vurmak vurabiliyorum
# yakmak yakabiliyorum
# yapmak yapabiliyorum
# yaratmak yaratabiliyorum
# yaşamak yaşayabiliyorum
# yazmak yazabiliyorum
# yemek yiyebiliyorum
# yürümek yürüyebiliyorum
